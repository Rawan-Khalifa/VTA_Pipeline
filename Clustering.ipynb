# %%
import os
import nibabel as nib
import numpy as np
import pandas as pd
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

def load_nifti(file_path):
    """Load a NIfTI file and return the data array."""
    nifti_data = nib.load(file_path)
    return nifti_data.get_fdata()

def binarize_mask(mask):
    """Convert the NIfTI data to a binary mask."""
    binary_mask = np.where(mask > 0, 1, 0)
    return binary_mask

# Load LEDD.csv file
ledd_path = '/Users/rwankhalifa/Downloads/LEDD.csv' 
ledd_data = pd.read_csv(ledd_path)

# Add a new column for LEDD value categorization
ledd_data['LEDD_category'] = ledd_data['Delta_LEDD'].apply(lambda x: 'Positive' if x > 0 else ('Negative' if x < 0 else 'Zero'))

# Base directory where patient data is stored
base_dir = '/Volumes/MORRISON/retro_clin'
all_patient_data = []

# Set a default shape for missing masks if needed (e.g., [1, 1, 1] if no prior knowledge)
default_shape = (394, 466, 378)  # Actual shape you expect from your NIfTI files

# Loop through each patient, load their stimulation files and binary masks
for patient_number in ledd_data['Patient Number']:
    # Remove the prefix 'PDa' and convert the rest to an integer
    patient_number_int = int(patient_number.replace('PDa', ''))
    
    patient_dir = f'PDa{patient_number_int:03d}'
    file_patient_number = str(patient_number_int)
    
    # Define stimulation file paths for both hemispheres
    stim_file_paths = {
        'right': f'{base_dir}/{patient_dir}/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd{file_patient_number}/rsub-leads_sim-binary_model-simbio_hemi-R.nii',
        'left': f'{base_dir}/{patient_dir}/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd{file_patient_number}/rsub-leads_sim-binary_model-simbio_hemi-L.nii'
    }
    
    # Initialize patient data
    patient_data = []
    
    # Load and binarize mask for each hemisphere
    for hemi, path in stim_file_paths.items():
        if os.path.exists(path):
            mask_data = load_nifti(path)
            binary_mask = binarize_mask(mask_data)
            patient_data.append(binary_mask.flatten())  # Flatten mask to a 1D array for clustering
        else:
            # Create a binary mask of zeros with the default shape when the file does not exist
            default_mask = np.zeros(default_shape)
            patient_data.append(default_mask.flatten())

    all_patient_data.append(np.concatenate(patient_data))

# Convert patient data to NumPy array for clustering
patient_data_matrix = np.array(all_patient_data)

# Standardize the data before clustering
scaler = StandardScaler()
scaled_data = scaler.fit_transform(patient_data_matrix)

# Apply KMeans clustering
kmeans = KMeans(n_clusters=3, random_state=42)
clusters = kmeans.fit_predict(scaled_data)

# Add cluster labels to LEDD data
ledd_data['Cluster'] = clusters

# Save or display the updated DataFrame for analysis
ledd_data.to_csv('/Users/rwankhalifa/Downloads/clusters.csv', index=False)  # Update with desired output path
print(ledd_data)

# %%
import nibabel as nib

# Load the NIfTI file to determine the default shape
nifti_file_path = '/Volumes/MORRISON/retro_clin/PDa144/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd144/rsub-leads_sim-binary_model-simbio_hemi-L.nii'  # Update this path with the location of your NIfTI file
nifti_data = nib.load(nifti_file_path)
default_shape = nifti_data.shape

print("Default shape of the NIfTI file:", default_shape)
# Out:
# Default shape of the NIfTI file: (394, 466, 378)

# %%
import os
import nibabel as nib
import numpy as np
import pandas as pd
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

def load_nifti(file_path):
    """Load a NIfTI file and return the data array."""
    print(f"Loading NIfTI file from {file_path}...")
    nifti_data = nib.load(file_path)
    print(f"NIfTI file loaded from {file_path}.")
    return nifti_data.get_fdata()

def binarize_mask(mask):
    """Convert the NIfTI data to a binary mask."""
    binary_mask = np.where(mask > 0, 1, 0)
    return binary_mask

# Load LEDD.csv file
ledd_path = '/Users/rwankhalifa/Downloads/LEDD.csv' 
print(f"Loading LEDD data from {ledd_path}...")
ledd_data = pd.read_csv(ledd_path)
print("LEDD data loaded.")

# Add a new column for LEDD value categorization
print("Categorizing LEDD values...")
ledd_data['LEDD_category'] = ledd_data['Delta_LEDD'].apply(lambda x: 'Positive' if x > 0 else ('Negative' if x < 0 else 'Zero'))
print("LEDD values categorized.")

# Base directory where patient data is stored
base_dir = '/Volumes/MORRISON/retro_clin'
all_patient_data = []

# Set a default shape for missing masks if needed
default_shape = (394, 466, 378)  # Replace with the actual shape of your NIfTI files

print("Starting to process each patient...")

# Loop through each patient, load their stimulation files and binary masks
for idx, patient_number in enumerate(ledd_data['Patient Number']):
    # Remove the prefix 'PDa' and convert the rest to an integer
    patient_number_int = int(patient_number.replace('PDa', ''))
    
    # Only process patients from 20 to 144
    if patient_number_int < 20:
        continue
    elif patient_number_int > 144:
        print(f"Reached patient number {patient_number}, stopping processing.")
        break

    print(f"Processing patient {idx + 1}/{len(ledd_data['Patient Number'])}: {patient_number}")

    patient_dir = f'PDa{patient_number_int:03d}'
    file_patient_number = str(patient_number_int)
    
    # Define stimulation file paths for both hemispheres
    stim_file_paths = {
        'right': f'{base_dir}/{patient_dir}/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd{file_patient_number}/rsub-leads_sim-binary_model-simbio_hemi-R.nii',
        'left': f'{base_dir}/{patient_dir}/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd{file_patient_number}/rsub-leads_sim-binary_model-simbio_hemi-L.nii'
    }
    
    # Initialize patient data
    patient_data = []
    
    # Load and binarize mask for each hemisphere
    for hemi, path in stim_file_paths.items():
        print(f"Checking file existence for {hemi} hemisphere: {path}")
        if os.path.exists(path):
            print(f"File found. Loading and processing {hemi} hemisphere...")
            mask_data = load_nifti(path)
            binary_mask = binarize_mask(mask_data)
            patient_data.append(binary_mask.flatten())  # Flatten mask to a 1D array for clustering
            print(f"{hemi.capitalize()} hemisphere processed.")
        else:
            print(f"File not found for {hemi} hemisphere. Using default mask.")
            default_mask = np.zeros(default_shape)
            patient_data.append(default_mask.flatten())

    print(f"Finished processing patient {patient_number}.")
    all_patient_data.append(np.concatenate(patient_data))

print("All patients processed. Preparing data for clustering...")

# Convert patient data to NumPy array for clustering
patient_data_matrix = np.array(all_patient_data)

# Standardize the data before clustering
print("Standardizing data...")
scaler = StandardScaler()
scaled_data = scaler.fit_transform(patient_data_matrix)
print("Data standardized.")

# Apply KMeans clustering
print("Applying KMeans clustering...")
kmeans = KMeans(n_clusters=3, random_state=42)
clusters = kmeans.fit_predict(scaled_data)
print("KMeans clustering applied.")

# Add cluster labels to LEDD data
ledd_data['Cluster'] = clusters

# Save or display the updated DataFrame for analysis
output_path = '/Users/rwankhalifa/Downloads/clusters.csv'
ledd_data.to_csv(output_path, index=False)
print(f"Cluster data saved to {output_path}.")
print(ledd_data)
# Out:
# Loading LEDD data from /Users/rwankhalifa/Downloads/LEDD.csv...
# LEDD data loaded.
# Categorizing LEDD values...
# LEDD values categorized.
# Starting to process each patient...
# Processing patient 15/268: PDa020
# Checking file existence for right hemisphere: /Volumes/MORRISON/retro_clin/PDa020/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd20/rsub-leads_sim-binary_model-simbio_hemi-R.nii
# File found. Loading and processing right hemisphere...
# Loading NIfTI file from /Volumes/MORRISON/retro_clin/PDa020/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd20/rsub-leads_sim-binary_model-simbio_hemi-R.nii...
# NIfTI file loaded from /Volumes/MORRISON/retro_clin/PDa020/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd20/rsub-leads_sim-binary_model-simbio_hemi-R.nii.
# Right hemisphere processed.
# Checking file existence for left hemisphere: /Volumes/MORRISON/retro_clin/PDa020/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd20/rsub-leads_sim-binary_model-simbio_hemi-L.nii
# File found. Loading and processing left hemisphere...
# Loading NIfTI file from /Volumes/MORRISON/retro_clin/PDa020/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd20/rsub-leads_sim-binary_model-simbio_hemi-L.nii...
# NIfTI file loaded from /Volumes/MORRISON/retro_clin/PDa020/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd20/rsub-leads_sim-binary_model-simbio_hemi-L.nii.
# Left hemisphere processed.
# Finished processing patient PDa020.
# Processing patient 16/268: PDa021
# Checking file existence for right hemisphere: /Volumes/MORRISON/retro_clin/PDa021/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd21/rsub-leads_sim-binary_model-simbio_hemi-R.nii
# File found. Loading and processing right hemisphere...
# Loading NIfTI file from /Volumes/MORRISON/retro_clin/PDa021/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd21/rsub-leads_sim-binary_model-simbio_hemi-R.nii...
# NIfTI file loaded from /Volumes/MORRISON/retro_clin/PDa021/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd21/rsub-leads_sim-binary_model-simbio_hemi-R.nii.
# Right hemisphere processed.
# Checking file existence for left hemisphere: /Volumes/MORRISON/retro_clin/PDa021/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd21/rsub-leads_sim-binary_model-simbio_hemi-L.nii
# File not found for left hemisphere. Using default mask.
# Finished processing patient PDa021.
# Processing patient 17/268: PDa022
# Checking file existence for right hemisphere: /Volumes/MORRISON/retro_clin/PDa022/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd22/rsub-leads_sim-binary_model-simbio_hemi-R.nii
# File not found for right hemisphere. Using default mask.
# Checking file existence for left hemisphere: /Volumes/MORRISON/retro_clin/PDa022/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd22/rsub-leads_sim-binary_model-simbio_hemi-L.nii
# File found. Loading and processing left hemisphere...
# Loading NIfTI file from /Volumes/MORRISON/retro_clin/PDa022/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd22/rsub-leads_sim-binary_model-simbio_hemi-L.nii...
# NIfTI file loaded from /Volumes/MORRISON/retro_clin/PDa022/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd22/rsub-leads_sim-binary_model-simbio_hemi-L.nii.
# Left hemisphere processed.
# Finished processing patient PDa022.
# Processing patient 18/268: PDa023
# Checking file existence for right hemisphere: /Volumes/MORRISON/retro_clin/PDa023/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd23/rsub-leads_sim-binary_model-simbio_hemi-R.nii
# File not found for right hemisphere. Using default mask.
# Checking file existence for left hemisphere: /Volumes/MORRISON/retro_clin/PDa023/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd23/rsub-leads_sim-binary_model-simbio_hemi-L.nii
# File found. Loading and processing left hemisphere...
# Loading NIfTI file from /Volumes/MORRISON/retro_clin/PDa023/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd23/rsub-leads_sim-binary_model-simbio_hemi-L.nii...
# NIfTI file loaded from /Volumes/MORRISON/retro_clin/PDa023/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd23/rsub-leads_sim-binary_model-simbio_hemi-L.nii.
# Left hemisphere processed.
# Finished processing patient PDa023.
# Processing patient 19/268: PDa024
# Checking file existence for right hemisphere: /Volumes/MORRISON/retro_clin/PDa024/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd24/rsub-leads_sim-binary_model-simbio_hemi-R.nii
# File found. Loading and processing right hemisphere...
# Loading NIfTI file from /Volumes/MORRISON/retro_clin/PDa024/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd24/rsub-leads_sim-binary_model-simbio_hemi-R.nii...
# NIfTI file loaded from /Volumes/MORRISON/retro_clin/PDa024/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd24/rsub-leads_sim-binary_model-simbio_hemi-R.nii.
# Right hemisphere processed.
# Checking file existence for left hemisphere: /Volumes/MORRISON/retro_clin/PDa024/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd24/rsub-leads_sim-binary_model-simbio_hemi-L.nii
# File found. Loading and processing left hemisphere...
# Loading NIfTI file from /Volumes/MORRISON/retro_clin/PDa024/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd24/rsub-leads_sim-binary_model-simbio_hemi-L.nii...
# NIfTI file loaded from /Volumes/MORRISON/retro_clin/PDa024/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd24/rsub-leads_sim-binary_model-simbio_hemi-L.nii.
# Left hemisphere processed.
# Finished processing patient PDa024.
# Processing patient 20/268: PDa025
# Checking file existence for right hemisphere: /Volumes/MORRISON/retro_clin/PDa025/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd25/rsub-leads_sim-binary_model-simbio_hemi-R.nii
# File found. Loading and processing right hemisphere...
# Loading NIfTI file from /Volumes/MORRISON/retro_clin/PDa025/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd25/rsub-leads_sim-binary_model-simbio_hemi-R.nii...
# NIfTI file loaded from /Volumes/MORRISON/retro_clin/PDa025/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd25/rsub-leads_sim-binary_model-simbio_hemi-R.nii.
# Right hemisphere processed.
# Checking file existence for left hemisphere: /Volumes/MORRISON/retro_clin/PDa025/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd25/rsub-leads_sim-binary_model-simbio_hemi-L.nii
# File not found for left hemisphere. Using default mask.
# Finished processing patient PDa025.
# Processing patient 21/268: PDa028
# Checking file existence for right hemisphere: /Volumes/MORRISON/retro_clin/PDa028/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd28/rsub-leads_sim-binary_model-simbio_hemi-R.nii
# File not found for right hemisphere. Using default mask.
# Checking file existence for left hemisphere: /Volumes/MORRISON/retro_clin/PDa028/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd28/rsub-leads_sim-binary_model-simbio_hemi-L.nii
# File not found for left hemisphere. Using default mask.
# Finished processing patient PDa028.
# Processing patient 22/268: PDa029
# Checking file existence for right hemisphere: /Volumes/MORRISON/retro_clin/PDa029/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd29/rsub-leads_sim-binary_model-simbio_hemi-R.nii
# File found. Loading and processing right hemisphere...
# Loading NIfTI file from /Volumes/MORRISON/retro_clin/PDa029/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd29/rsub-leads_sim-binary_model-simbio_hemi-R.nii...
# NIfTI file loaded from /Volumes/MORRISON/retro_clin/PDa029/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd29/rsub-leads_sim-binary_model-simbio_hemi-R.nii.
# Right hemisphere processed.
# Checking file existence for left hemisphere: /Volumes/MORRISON/retro_clin/PDa029/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd29/rsub-leads_sim-binary_model-simbio_hemi-L.nii
# File not found for left hemisphere. Using default mask.
# Finished processing patient PDa029.
# Processing patient 23/268: PDa030
# Checking file existence for right hemisphere: /Volumes/MORRISON/retro_clin/PDa030/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd30/rsub-leads_sim-binary_model-simbio_hemi-R.nii
# File not found for right hemisphere. Using default mask.
# Checking file existence for left hemisphere: /Volumes/MORRISON/retro_clin/PDa030/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd30/rsub-leads_sim-binary_model-simbio_hemi-L.nii
# File not found for left hemisphere. Using default mask.
# Finished processing patient PDa030.
# Processing patient 24/268: PDa031
# Checking file existence for right hemisphere: /Volumes/MORRISON/retro_clin/PDa031/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd31/rsub-leads_sim-binary_model-simbio_hemi-R.nii
# File found. Loading and processing right hemisphere...
# Loading NIfTI file from /Volumes/MORRISON/retro_clin/PDa031/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd31/rsub-leads_sim-binary_model-simbio_hemi-R.nii...
# NIfTI file loaded from /Volumes/MORRISON/retro_clin/PDa031/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd31/rsub-leads_sim-binary_model-simbio_hemi-R.nii.
# Right hemisphere processed.
# Checking file existence for left hemisphere: /Volumes/MORRISON/retro_clin/PDa031/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd31/rsub-leads_sim-binary_model-simbio_hemi-L.nii
# File found. Loading and processing left hemisphere...
# Loading NIfTI file from /Volumes/MORRISON/retro_clin/PDa031/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd31/rsub-leads_sim-binary_model-simbio_hemi-L.nii...
# NIfTI file loaded from /Volumes/MORRISON/retro_clin/PDa031/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd31/rsub-leads_sim-binary_model-simbio_hemi-L.nii.
# Left hemisphere processed.
# Finished processing patient PDa031.
# Processing patient 25/268: PDa032
# Checking file existence for right hemisphere: /Volumes/MORRISON/retro_clin/PDa032/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd32/rsub-leads_sim-binary_model-simbio_hemi-R.nii
# File found. Loading and processing right hemisphere...
# Loading NIfTI file from /Volumes/MORRISON/retro_clin/PDa032/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd32/rsub-leads_sim-binary_model-simbio_hemi-R.nii...
# NIfTI file loaded from /Volumes/MORRISON/retro_clin/PDa032/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd32/rsub-leads_sim-binary_model-simbio_hemi-R.nii.
# Right hemisphere processed.
# Checking file existence for left hemisphere: /Volumes/MORRISON/retro_clin/PDa032/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd32/rsub-leads_sim-binary_model-simbio_hemi-L.nii
# File not found for left hemisphere. Using default mask.
# Finished processing patient PDa032.
# Processing patient 26/268: PDa033
# Checking file existence for right hemisphere: /Volumes/MORRISON/retro_clin/PDa033/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd33/rsub-leads_sim-binary_model-simbio_hemi-R.nii
# File not found for right hemisphere. Using default mask.
# Checking file existence for left hemisphere: /Volumes/MORRISON/retro_clin/PDa033/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd33/rsub-leads_sim-binary_model-simbio_hemi-L.nii
# File not found for left hemisphere. Using default mask.
# Finished processing patient PDa033.
# Processing patient 27/268: PDa034
# Checking file existence for right hemisphere: /Volumes/MORRISON/retro_clin/PDa034/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd34/rsub-leads_sim-binary_model-simbio_hemi-R.nii
# File not found for right hemisphere. Using default mask.
# Checking file existence for left hemisphere: /Volumes/MORRISON/retro_clin/PDa034/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd34/rsub-leads_sim-binary_model-simbio_hemi-L.nii
# File not found for left hemisphere. Using default mask.
# Finished processing patient PDa034.
# Processing patient 28/268: PDa035
# Checking file existence for right hemisphere: /Volumes/MORRISON/retro_clin/PDa035/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd35/rsub-leads_sim-binary_model-simbio_hemi-R.nii
# File found. Loading and processing right hemisphere...
# Loading NIfTI file from /Volumes/MORRISON/retro_clin/PDa035/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd35/rsub-leads_sim-binary_model-simbio_hemi-R.nii...
# NIfTI file loaded from /Volumes/MORRISON/retro_clin/PDa035/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd35/rsub-leads_sim-binary_model-simbio_hemi-R.nii.
# Right hemisphere processed.
# Checking file existence for left hemisphere: /Volumes/MORRISON/retro_clin/PDa035/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd35/rsub-leads_sim-binary_model-simbio_hemi-L.nii
# File not found for left hemisphere. Using default mask.
# Finished processing patient PDa035.
# Processing patient 29/268: PDa036
# Checking file existence for right hemisphere: /Volumes/MORRISON/retro_clin/PDa036/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd36/rsub-leads_sim-binary_model-simbio_hemi-R.nii
# File not found for right hemisphere. Using default mask.
# Checking file existence for left hemisphere: /Volumes/MORRISON/retro_clin/PDa036/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd36/rsub-leads_sim-binary_model-simbio_hemi-L.nii
# File not found for left hemisphere. Using default mask.
# Finished processing patient PDa036.
# Processing patient 30/268: PDa037
# Checking file existence for right hemisphere: /Volumes/MORRISON/retro_clin/PDa037/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd37/rsub-leads_sim-binary_model-simbio_hemi-R.nii
# File found. Loading and processing right hemisphere...
# Loading NIfTI file from /Volumes/MORRISON/retro_clin/PDa037/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd37/rsub-leads_sim-binary_model-simbio_hemi-R.nii...
# NIfTI file loaded from /Volumes/MORRISON/retro_clin/PDa037/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd37/rsub-leads_sim-binary_model-simbio_hemi-R.nii.
# Right hemisphere processed.
# Checking file existence for left hemisphere: /Volumes/MORRISON/retro_clin/PDa037/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd37/rsub-leads_sim-binary_model-simbio_hemi-L.nii
# File not found for left hemisphere. Using default mask.
# Finished processing patient PDa037.
# Processing patient 31/268: PDa038
# Checking file existence for right hemisphere: /Volumes/MORRISON/retro_clin/PDa038/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd38/rsub-leads_sim-binary_model-simbio_hemi-R.nii
# File not found for right hemisphere. Using default mask.
# Checking file existence for left hemisphere: /Volumes/MORRISON/retro_clin/PDa038/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd38/rsub-leads_sim-binary_model-simbio_hemi-L.nii
# File not found for left hemisphere. Using default mask.
# Finished processing patient PDa038.
# Processing patient 32/268: PDa039
# Checking file existence for right hemisphere: /Volumes/MORRISON/retro_clin/PDa039/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd39/rsub-leads_sim-binary_model-simbio_hemi-R.nii
# File not found for right hemisphere. Using default mask.
# Checking file existence for left hemisphere: /Volumes/MORRISON/retro_clin/PDa039/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd39/rsub-leads_sim-binary_model-simbio_hemi-L.nii
# File found. Loading and processing left hemisphere...
# Loading NIfTI file from /Volumes/MORRISON/retro_clin/PDa039/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd39/rsub-leads_sim-binary_model-simbio_hemi-L.nii...
# NIfTI file loaded from /Volumes/MORRISON/retro_clin/PDa039/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd39/rsub-leads_sim-binary_model-simbio_hemi-L.nii.
# Left hemisphere processed.
# Finished processing patient PDa039.
# Processing patient 33/268: PDa040
# Checking file existence for right hemisphere: /Volumes/MORRISON/retro_clin/PDa040/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd40/rsub-leads_sim-binary_model-simbio_hemi-R.nii
# File found. Loading and processing right hemisphere...
# Loading NIfTI file from /Volumes/MORRISON/retro_clin/PDa040/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd40/rsub-leads_sim-binary_model-simbio_hemi-R.nii...
# NIfTI file loaded from /Volumes/MORRISON/retro_clin/PDa040/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd40/rsub-leads_sim-binary_model-simbio_hemi-R.nii.
# Right hemisphere processed.
# Checking file existence for left hemisphere: /Volumes/MORRISON/retro_clin/PDa040/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd40/rsub-leads_sim-binary_model-simbio_hemi-L.nii
# File found. Loading and processing left hemisphere...
# Loading NIfTI file from /Volumes/MORRISON/retro_clin/PDa040/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd40/rsub-leads_sim-binary_model-simbio_hemi-L.nii...
# NIfTI file loaded from /Volumes/MORRISON/retro_clin/PDa040/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd40/rsub-leads_sim-binary_model-simbio_hemi-L.nii.
# Left hemisphere processed.
# Finished processing patient PDa040.
# Processing patient 34/268: PDa042
# Checking file existence for right hemisphere: /Volumes/MORRISON/retro_clin/PDa042/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd42/rsub-leads_sim-binary_model-simbio_hemi-R.nii
# File not found for right hemisphere. Using default mask.
# Checking file existence for left hemisphere: /Volumes/MORRISON/retro_clin/PDa042/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd42/rsub-leads_sim-binary_model-simbio_hemi-L.nii
# File not found for left hemisphere. Using default mask.
# Finished processing patient PDa042.
# Processing patient 35/268: PDa043
# Checking file existence for right hemisphere: /Volumes/MORRISON/retro_clin/PDa043/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd43/rsub-leads_sim-binary_model-simbio_hemi-R.nii
# File found. Loading and processing right hemisphere...
# Loading NIfTI file from /Volumes/MORRISON/retro_clin/PDa043/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd43/rsub-leads_sim-binary_model-simbio_hemi-R.nii...
# NIfTI file loaded from /Volumes/MORRISON/retro_clin/PDa043/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd43/rsub-leads_sim-binary_model-simbio_hemi-R.nii.
# Right hemisphere processed.
# Checking file existence for left hemisphere: /Volumes/MORRISON/retro_clin/PDa043/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd43/rsub-leads_sim-binary_model-simbio_hemi-L.nii
# File not found for left hemisphere. Using default mask.
# Finished processing patient PDa043.
# Processing patient 36/268: PDa044
# Checking file existence for right hemisphere: /Volumes/MORRISON/retro_clin/PDa044/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd44/rsub-leads_sim-binary_model-simbio_hemi-R.nii
# File not found for right hemisphere. Using default mask.
# Checking file existence for left hemisphere: /Volumes/MORRISON/retro_clin/PDa044/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd44/rsub-leads_sim-binary_model-simbio_hemi-L.nii
# File not found for left hemisphere. Using default mask.
# Finished processing patient PDa044.
# Processing patient 37/268: PDa045
# Checking file existence for right hemisphere: /Volumes/MORRISON/retro_clin/PDa045/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd45/rsub-leads_sim-binary_model-simbio_hemi-R.nii
# File found. Loading and processing right hemisphere...
# Loading NIfTI file from /Volumes/MORRISON/retro_clin/PDa045/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd45/rsub-leads_sim-binary_model-simbio_hemi-R.nii...
# NIfTI file loaded from /Volumes/MORRISON/retro_clin/PDa045/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd45/rsub-leads_sim-binary_model-simbio_hemi-R.nii.
# Right hemisphere processed.
# Checking file existence for left hemisphere: /Volumes/MORRISON/retro_clin/PDa045/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd45/rsub-leads_sim-binary_model-simbio_hemi-L.nii
# File found. Loading and processing left hemisphere...
# Loading NIfTI file from /Volumes/MORRISON/retro_clin/PDa045/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd45/rsub-leads_sim-binary_model-simbio_hemi-L.nii...
# NIfTI file loaded from /Volumes/MORRISON/retro_clin/PDa045/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd45/rsub-leads_sim-binary_model-simbio_hemi-L.nii.
# Left hemisphere processed.
# Finished processing patient PDa045.
# Processing patient 38/268: PDa046
# Checking file existence for right hemisphere: /Volumes/MORRISON/retro_clin/PDa046/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd46/rsub-leads_sim-binary_model-simbio_hemi-R.nii
# File found. Loading and processing right hemisphere...
# Loading NIfTI file from /Volumes/MORRISON/retro_clin/PDa046/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd46/rsub-leads_sim-binary_model-simbio_hemi-R.nii...
# NIfTI file loaded from /Volumes/MORRISON/retro_clin/PDa046/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd46/rsub-leads_sim-binary_model-simbio_hemi-R.nii.
# Right hemisphere processed.
# Checking file existence for left hemisphere: /Volumes/MORRISON/retro_clin/PDa046/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd46/rsub-leads_sim-binary_model-simbio_hemi-L.nii
# File found. Loading and processing left hemisphere...
# Loading NIfTI file from /Volumes/MORRISON/retro_clin/PDa046/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd46/rsub-leads_sim-binary_model-simbio_hemi-L.nii...
# NIfTI file loaded from /Volumes/MORRISON/retro_clin/PDa046/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd46/rsub-leads_sim-binary_model-simbio_hemi-L.nii.
# Left hemisphere processed.
# Finished processing patient PDa046.
# Processing patient 39/268: PDa047
# Checking file existence for right hemisphere: /Volumes/MORRISON/retro_clin/PDa047/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd47/rsub-leads_sim-binary_model-simbio_hemi-R.nii
# File not found for right hemisphere. Using default mask.
# Checking file existence for left hemisphere: /Volumes/MORRISON/retro_clin/PDa047/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd47/rsub-leads_sim-binary_model-simbio_hemi-L.nii
# File not found for left hemisphere. Using default mask.
# Finished processing patient PDa047.
# Processing patient 40/268: PDa048
# Checking file existence for right hemisphere: /Volumes/MORRISON/retro_clin/PDa048/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd48/rsub-leads_sim-binary_model-simbio_hemi-R.nii
# File found. Loading and processing right hemisphere...
# Loading NIfTI file from /Volumes/MORRISON/retro_clin/PDa048/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd48/rsub-leads_sim-binary_model-simbio_hemi-R.nii...
# NIfTI file loaded from /Volumes/MORRISON/retro_clin/PDa048/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd48/rsub-leads_sim-binary_model-simbio_hemi-R.nii.
# Right hemisphere processed.
# Checking file existence for left hemisphere: /Volumes/MORRISON/retro_clin/PDa048/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd48/rsub-leads_sim-binary_model-simbio_hemi-L.nii
# File found. Loading and processing left hemisphere...
# Loading NIfTI file from /Volumes/MORRISON/retro_clin/PDa048/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd48/rsub-leads_sim-binary_model-simbio_hemi-L.nii...
# NIfTI file loaded from /Volumes/MORRISON/retro_clin/PDa048/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd48/rsub-leads_sim-binary_model-simbio_hemi-L.nii.
# Left hemisphere processed.
# Finished processing patient PDa048.
# Processing patient 41/268: PDa050
# Checking file existence for right hemisphere: /Volumes/MORRISON/retro_clin/PDa050/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd50/rsub-leads_sim-binary_model-simbio_hemi-R.nii
# File found. Loading and processing right hemisphere...
# Loading NIfTI file from /Volumes/MORRISON/retro_clin/PDa050/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd50/rsub-leads_sim-binary_model-simbio_hemi-R.nii...
# NIfTI file loaded from /Volumes/MORRISON/retro_clin/PDa050/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd50/rsub-leads_sim-binary_model-simbio_hemi-R.nii.
# Right hemisphere processed.
# Checking file existence for left hemisphere: /Volumes/MORRISON/retro_clin/PDa050/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd50/rsub-leads_sim-binary_model-simbio_hemi-L.nii
# File found. Loading and processing left hemisphere...
# Loading NIfTI file from /Volumes/MORRISON/retro_clin/PDa050/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd50/rsub-leads_sim-binary_model-simbio_hemi-L.nii...
# NIfTI file loaded from /Volumes/MORRISON/retro_clin/PDa050/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd50/rsub-leads_sim-binary_model-simbio_hemi-L.nii.
# Left hemisphere processed.
# Finished processing patient PDa050.
# Processing patient 42/268: PDa051
# Checking file existence for right hemisphere: /Volumes/MORRISON/retro_clin/PDa051/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd51/rsub-leads_sim-binary_model-simbio_hemi-R.nii
# File not found for right hemisphere. Using default mask.
# Checking file existence for left hemisphere: /Volumes/MORRISON/retro_clin/PDa051/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd51/rsub-leads_sim-binary_model-simbio_hemi-L.nii
# File not found for left hemisphere. Using default mask.
# Finished processing patient PDa051.
# Processing patient 43/268: PDa053
# Checking file existence for right hemisphere: /Volumes/MORRISON/retro_clin/PDa053/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd53/rsub-leads_sim-binary_model-simbio_hemi-R.nii
# File found. Loading and processing right hemisphere...
# Loading NIfTI file from /Volumes/MORRISON/retro_clin/PDa053/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd53/rsub-leads_sim-binary_model-simbio_hemi-R.nii...
# NIfTI file loaded from /Volumes/MORRISON/retro_clin/PDa053/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd53/rsub-leads_sim-binary_model-simbio_hemi-R.nii.
# Right hemisphere processed.
# Checking file existence for left hemisphere: /Volumes/MORRISON/retro_clin/PDa053/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd53/rsub-leads_sim-binary_model-simbio_hemi-L.nii
# File found. Loading and processing left hemisphere...
# Loading NIfTI file from /Volumes/MORRISON/retro_clin/PDa053/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd53/rsub-leads_sim-binary_model-simbio_hemi-L.nii...
# NIfTI file loaded from /Volumes/MORRISON/retro_clin/PDa053/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd53/rsub-leads_sim-binary_model-simbio_hemi-L.nii.
# Left hemisphere processed.
# Finished processing patient PDa053.
# Processing patient 44/268: PDa054
# Checking file existence for right hemisphere: /Volumes/MORRISON/retro_clin/PDa054/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd54/rsub-leads_sim-binary_model-simbio_hemi-R.nii
# File found. Loading and processing right hemisphere...
# Loading NIfTI file from /Volumes/MORRISON/retro_clin/PDa054/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd54/rsub-leads_sim-binary_model-simbio_hemi-R.nii...
# NIfTI file loaded from /Volumes/MORRISON/retro_clin/PDa054/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd54/rsub-leads_sim-binary_model-simbio_hemi-R.nii.
# Right hemisphere processed.
# Checking file existence for left hemisphere: /Volumes/MORRISON/retro_clin/PDa054/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd54/rsub-leads_sim-binary_model-simbio_hemi-L.nii
# File not found for left hemisphere. Using default mask.
# Finished processing patient PDa054.
# Processing patient 45/268: PDa055
# Checking file existence for right hemisphere: /Volumes/MORRISON/retro_clin/PDa055/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd55/rsub-leads_sim-binary_model-simbio_hemi-R.nii
# File not found for right hemisphere. Using default mask.
# Checking file existence for left hemisphere: /Volumes/MORRISON/retro_clin/PDa055/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd55/rsub-leads_sim-binary_model-simbio_hemi-L.nii
# File not found for left hemisphere. Using default mask.
# Finished processing patient PDa055.
# Processing patient 46/268: PDa056
# Checking file existence for right hemisphere: /Volumes/MORRISON/retro_clin/PDa056/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd56/rsub-leads_sim-binary_model-simbio_hemi-R.nii
# File not found for right hemisphere. Using default mask.
# Checking file existence for left hemisphere: /Volumes/MORRISON/retro_clin/PDa056/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd56/rsub-leads_sim-binary_model-simbio_hemi-L.nii
# File not found for left hemisphere. Using default mask.
# Finished processing patient PDa056.
# Processing patient 47/268: PDa057
# Checking file existence for right hemisphere: /Volumes/MORRISON/retro_clin/PDa057/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd57/rsub-leads_sim-binary_model-simbio_hemi-R.nii
# File found. Loading and processing right hemisphere...
# Loading NIfTI file from /Volumes/MORRISON/retro_clin/PDa057/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd57/rsub-leads_sim-binary_model-simbio_hemi-R.nii...
# NIfTI file loaded from /Volumes/MORRISON/retro_clin/PDa057/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd57/rsub-leads_sim-binary_model-simbio_hemi-R.nii.
# Right hemisphere processed.
# Checking file existence for left hemisphere: /Volumes/MORRISON/retro_clin/PDa057/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd57/rsub-leads_sim-binary_model-simbio_hemi-L.nii
# File found. Loading and processing left hemisphere...
# Loading NIfTI file from /Volumes/MORRISON/retro_clin/PDa057/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd57/rsub-leads_sim-binary_model-simbio_hemi-L.nii...
# NIfTI file loaded from /Volumes/MORRISON/retro_clin/PDa057/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd57/rsub-leads_sim-binary_model-simbio_hemi-L.nii.
# Left hemisphere processed.
# Finished processing patient PDa057.
# Processing patient 48/268: PDa058
# Checking file existence for right hemisphere: /Volumes/MORRISON/retro_clin/PDa058/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd58/rsub-leads_sim-binary_model-simbio_hemi-R.nii
# File not found for right hemisphere. Using default mask.
# Checking file existence for left hemisphere: /Volumes/MORRISON/retro_clin/PDa058/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd58/rsub-leads_sim-binary_model-simbio_hemi-L.nii
# File found. Loading and processing left hemisphere...
# Loading NIfTI file from /Volumes/MORRISON/retro_clin/PDa058/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd58/rsub-leads_sim-binary_model-simbio_hemi-L.nii...
# NIfTI file loaded from /Volumes/MORRISON/retro_clin/PDa058/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd58/rsub-leads_sim-binary_model-simbio_hemi-L.nii.
# Left hemisphere processed.
# Finished processing patient PDa058.
# Processing patient 49/268: PDa060
# Checking file existence for right hemisphere: /Volumes/MORRISON/retro_clin/PDa060/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd60/rsub-leads_sim-binary_model-simbio_hemi-R.nii
# File found. Loading and processing right hemisphere...
# Loading NIfTI file from /Volumes/MORRISON/retro_clin/PDa060/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd60/rsub-leads_sim-binary_model-simbio_hemi-R.nii...
# NIfTI file loaded from /Volumes/MORRISON/retro_clin/PDa060/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd60/rsub-leads_sim-binary_model-simbio_hemi-R.nii.
# Right hemisphere processed.
# Checking file existence for left hemisphere: /Volumes/MORRISON/retro_clin/PDa060/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd60/rsub-leads_sim-binary_model-simbio_hemi-L.nii
# File not found for left hemisphere. Using default mask.
# Finished processing patient PDa060.
# Processing patient 50/268: PDa061
# Checking file existence for right hemisphere: /Volumes/MORRISON/retro_clin/PDa061/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd61/rsub-leads_sim-binary_model-simbio_hemi-R.nii
# File not found for right hemisphere. Using default mask.
# Checking file existence for left hemisphere: /Volumes/MORRISON/retro_clin/PDa061/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd61/rsub-leads_sim-binary_model-simbio_hemi-L.nii
# File found. Loading and processing left hemisphere...
# Loading NIfTI file from /Volumes/MORRISON/retro_clin/PDa061/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd61/rsub-leads_sim-binary_model-simbio_hemi-L.nii...
# NIfTI file loaded from /Volumes/MORRISON/retro_clin/PDa061/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd61/rsub-leads_sim-binary_model-simbio_hemi-L.nii.
# Left hemisphere processed.
# Finished processing patient PDa061.
# Processing patient 51/268: PDa062
# Checking file existence for right hemisphere: /Volumes/MORRISON/retro_clin/PDa062/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd62/rsub-leads_sim-binary_model-simbio_hemi-R.nii
# File found. Loading and processing right hemisphere...
# Loading NIfTI file from /Volumes/MORRISON/retro_clin/PDa062/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd62/rsub-leads_sim-binary_model-simbio_hemi-R.nii...
# NIfTI file loaded from /Volumes/MORRISON/retro_clin/PDa062/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd62/rsub-leads_sim-binary_model-simbio_hemi-R.nii.
# Right hemisphere processed.
# Checking file existence for left hemisphere: /Volumes/MORRISON/retro_clin/PDa062/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd62/rsub-leads_sim-binary_model-simbio_hemi-L.nii
# File not found for left hemisphere. Using default mask.

# %%
# !pip install --upgrade pip
# !pip install --upgrade nibabel numpy pandas scikit-learn
# Out:
# Requirement already satisfied: pip in /opt/miniconda3/lib/python3.12/site-packages (24.2)
# Collecting nibabel
#   Downloading nibabel-5.2.1-py3-none-any.whl.metadata (8.8 kB)
# Collecting numpy
#   Downloading numpy-2.1.0-cp312-cp312-macosx_14_0_arm64.whl.metadata (60 kB)
# Collecting pandas
#   Downloading pandas-2.2.2-cp312-cp312-macosx_11_0_arm64.whl.metadata (19 kB)
# Collecting scikit-learn
#   Downloading scikit_learn-1.5.1-cp312-cp312-macosx_12_0_arm64.whl.metadata (12 kB)
# Requirement already satisfied: packaging>=17 in /opt/miniconda3/lib/python3.12/site-packages (from nibabel) (24.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/miniconda3/lib/python3.12/site-packages (from pandas) (2.9.0)
# Collecting pytz>=2020.1 (from pandas)
#   Downloading pytz-2024.1-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas)
#   Downloading tzdata-2024.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting scipy>=1.6.0 (from scikit-learn)
#   Downloading scipy-1.14.1-cp312-cp312-macosx_14_0_arm64.whl.metadata (60 kB)
# Collecting joblib>=1.2.0 (from scikit-learn)
#   Downloading joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn)
#   Downloading threadpoolctl-3.5.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: six>=1.5 in /opt/miniconda3/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Downloading nibabel-5.2.1-py3-none-any.whl (3.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 2.5 MB/s eta 0:00:00a 0:00:01
# Downloading numpy-2.1.0-cp312-cp312-macosx_14_0_arm64.whl (5.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 2.8 MB/s eta 0:00:00a 0:00:01
# Downloading pandas-2.2.2-cp312-cp312-macosx_11_0_arm64.whl (11.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 2.8 MB/s eta 0:00:00a 0:00:01
# Downloading scikit_learn-1.5.1-cp312-cp312-macosx_12_0_arm64.whl (11.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.0/11.0 MB 2.5 MB/s eta 0:00:00a 0:00:01
# Downloading joblib-1.4.2-py3-none-any.whl (301 kB)
# Downloading pytz-2024.1-py2.py3-none-any.whl (505 kB)
# Downloading scipy-1.14.1-cp312-cp312-macosx_14_0_arm64.whl (23.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.1/23.1 MB 2.7 MB/s eta 0:00:0000:0100:01
# Downloading threadpoolctl-3.5.0-py3-none-any.whl (18 kB)
# Downloading tzdata-2024.1-py2.py3-none-any.whl (345 kB)
# Installing collected packages: pytz, tzdata, threadpoolctl, numpy, joblib, scipy, pandas, nibabel, scikit-learn
# Successfully installed joblib-1.4.2 nibabel-5.2.1 numpy-2.1.0 pandas-2.2.2 pytz-2024.1 scikit-learn-1.5.1 scipy-1.14.1 threadpoolctl-3.5.0 tzdata-2024.1

# %%
import os
import nibabel as nib
import numpy as np
import pandas as pd
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

def load_nifti(file_path):
    """Load a NIfTI file with memory mapping to avoid loading the entire file into memory."""
    print(f"Loading NIfTI file from {file_path} with memory mapping...")
    nifti_data = nib.load(file_path, mmap=True)
    print(f"NIfTI file loaded from {file_path}.")
    return nifti_data.get_fdata()

def binarize_mask(mask):
    """Convert the NIfTI data to a binary mask."""
    binary_mask = np.where(mask > 0, 1, 0)
    return binary_mask

def process_patients(ledd_data, start_patient, end_patient):
    # Base directory where patient data is stored
    base_dir = '/Volumes/MORRISON/retro_clin'
    all_patient_data = []

    # Set a default shape for missing masks if needed
    default_shape = (394, 466, 378)  # Replace with the actual shape of your NIfTI files

    print("Starting to process each patient...")

    # Loop through each patient, load their stimulation files and binary masks
    for idx, patient_number in enumerate(ledd_data['Patient Number']):
        # Remove the prefix 'PDa' and convert the rest to an integer
        patient_number_int = int(patient_number.replace('PDa', ''))

        # Only process patients within the specified range
        if patient_number_int < start_patient:
            continue
        elif patient_number_int > end_patient:
            print(f"Reached patient number {patient_number}, stopping processing.")
            break

        print(f"Processing patient {idx + 1}/{len(ledd_data['Patient Number'])}: {patient_number}")

        patient_dir = f'PDa{patient_number_int:03d}'
        file_patient_number = str(patient_number_int)
        
        # Define stimulation file paths for both hemispheres
        stim_file_paths = {
            'right': f'{base_dir}/{patient_dir}/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd{file_patient_number}/rsub-leads_sim-binary_model-simbio_hemi-R.nii',
            'left': f'{base_dir}/{patient_dir}/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd{file_patient_number}/rsub-leads_sim-binary_model-simbio_hemi-L.nii'
        }
        
        # Initialize patient data
        patient_data = []
        
        # Load and binarize mask for each hemisphere
        for hemi, path in stim_file_paths.items():
            print(f"Checking file existence for {hemi} hemisphere: {path}")
            if os.path.exists(path):
                print(f"File found. Loading and processing {hemi} hemisphere...")
                mask_data = load_nifti(path)
                binary_mask = binarize_mask(mask_data)
                patient_data.append(binary_mask.flatten())  # Flatten mask to a 1D array for clustering
                print(f"{hemi.capitalize()} hemisphere processed.")
                # Free up memory by deleting large variables that are no longer needed
                del mask_data, binary_mask
            else:
                print(f"File not found for {hemi} hemisphere. Using default mask.")
                default_mask = np.zeros(default_shape)
                patient_data.append(default_mask.flatten())
                # Free up memory for the default mask as well
                del default_mask

        print(f"Finished processing patient {patient_number}.")
        all_patient_data.append(np.concatenate(patient_data))
        # Clear patient_data list to free up memory
        del patient_data

    print("All patients processed. Preparing data for clustering...")

    # Convert patient data to NumPy array for clustering
    patient_data_matrix = np.array(all_patient_data)
    # Clear all_patient_data to free up memory
    del all_patient_data

    # Standardize the data before clustering
    print("Standardizing data...")
    scaler = StandardScaler()
    scaled_data = scaler.fit_transform(patient_data_matrix)
    print("Data standardized.")
    # Clear patient_data_matrix to free up memory
    del patient_data_matrix

    # Apply KMeans clustering
    print("Applying KMeans clustering...")
    kmeans = KMeans(n_clusters=3, random_state=42)
    clusters = kmeans.fit_predict(scaled_data)
    print("KMeans clustering applied.")
    # Clear scaled_data to free up memory
    del scaled_data

    # Add cluster labels to LEDD data
    ledd_data['Cluster'] = clusters

    # Save or display the updated DataFrame for analysis
    output_path = '/Users/rwankhalifa/Downloads/clusters.csv'
    ledd_data.to_csv(output_path, index=False)
    print(f"Cluster data saved to {output_path}.")
    print(ledd_data)

# Load LEDD.csv file
ledd_path = '/Users/rwankhalifa/Downloads/LEDD.csv' 
print(f"Loading LEDD data from {ledd_path}...")
ledd_data = pd.read_csv(ledd_path)
print("LEDD data loaded.")

# Add a new column for LEDD value categorization
print("Categorizing LEDD values...")
ledd_data['LEDD_category'] = ledd_data['Delta_LEDD'].apply(lambda x: 'Positive' if x > 0 else ('Negative' if x < 0 else 'Zero'))
print("LEDD values categorized.")

# Process patients from 20 to 144 using the optimized function
process_patients(ledd_data, 20, 144)
# Out:
# Loading LEDD data from /Users/rwankhalifa/Downloads/LEDD.csv...
# LEDD data loaded.
# Categorizing LEDD values...
# LEDD values categorized.
# Starting to process each patient...
# Processing patient 15/268: PDa020
# Checking file existence for right hemisphere: /Volumes/MORRISON/retro_clin/PDa020/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd20/rsub-leads_sim-binary_model-simbio_hemi-R.nii
# File found. Loading and processing right hemisphere...
# Loading NIfTI file from /Volumes/MORRISON/retro_clin/PDa020/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd20/rsub-leads_sim-binary_model-simbio_hemi-R.nii with memory mapping...
# NIfTI file loaded from /Volumes/MORRISON/retro_clin/PDa020/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd20/rsub-leads_sim-binary_model-simbio_hemi-R.nii.
# Right hemisphere processed.
# Checking file existence for left hemisphere: /Volumes/MORRISON/retro_clin/PDa020/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd20/rsub-leads_sim-binary_model-simbio_hemi-L.nii
# File found. Loading and processing left hemisphere...
# Loading NIfTI file from /Volumes/MORRISON/retro_clin/PDa020/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd20/rsub-leads_sim-binary_model-simbio_hemi-L.nii with memory mapping...
# NIfTI file loaded from /Volumes/MORRISON/retro_clin/PDa020/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd20/rsub-leads_sim-binary_model-simbio_hemi-L.nii.
# Left hemisphere processed.
# Finished processing patient PDa020.
# Processing patient 16/268: PDa021
# Checking file existence for right hemisphere: /Volumes/MORRISON/retro_clin/PDa021/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd21/rsub-leads_sim-binary_model-simbio_hemi-R.nii
# File found. Loading and processing right hemisphere...
# Loading NIfTI file from /Volumes/MORRISON/retro_clin/PDa021/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd21/rsub-leads_sim-binary_model-simbio_hemi-R.nii with memory mapping...
# NIfTI file loaded from /Volumes/MORRISON/retro_clin/PDa021/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd21/rsub-leads_sim-binary_model-simbio_hemi-R.nii.
# Right hemisphere processed.
# Checking file existence for left hemisphere: /Volumes/MORRISON/retro_clin/PDa021/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd21/rsub-leads_sim-binary_model-simbio_hemi-L.nii
# File not found for left hemisphere. Using default mask.
# Finished processing patient PDa021.
# Processing patient 17/268: PDa022
# Checking file existence for right hemisphere: /Volumes/MORRISON/retro_clin/PDa022/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd22/rsub-leads_sim-binary_model-simbio_hemi-R.nii
# File not found for right hemisphere. Using default mask.
# Checking file existence for left hemisphere: /Volumes/MORRISON/retro_clin/PDa022/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd22/rsub-leads_sim-binary_model-simbio_hemi-L.nii
# File found. Loading and processing left hemisphere...
# Loading NIfTI file from /Volumes/MORRISON/retro_clin/PDa022/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd22/rsub-leads_sim-binary_model-simbio_hemi-L.nii with memory mapping...
# NIfTI file loaded from /Volumes/MORRISON/retro_clin/PDa022/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd22/rsub-leads_sim-binary_model-simbio_hemi-L.nii.
# Left hemisphere processed.
# Finished processing patient PDa022.
# Processing patient 18/268: PDa023
# Checking file existence for right hemisphere: /Volumes/MORRISON/retro_clin/PDa023/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd23/rsub-leads_sim-binary_model-simbio_hemi-R.nii
# File not found for right hemisphere. Using default mask.
# Checking file existence for left hemisphere: /Volumes/MORRISON/retro_clin/PDa023/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd23/rsub-leads_sim-binary_model-simbio_hemi-L.nii
# File found. Loading and processing left hemisphere...
# Loading NIfTI file from /Volumes/MORRISON/retro_clin/PDa023/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd23/rsub-leads_sim-binary_model-simbio_hemi-L.nii with memory mapping...
# NIfTI file loaded from /Volumes/MORRISON/retro_clin/PDa023/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd23/rsub-leads_sim-binary_model-simbio_hemi-L.nii.
# Left hemisphere processed.
# Finished processing patient PDa023.
# Processing patient 19/268: PDa024
# Checking file existence for right hemisphere: /Volumes/MORRISON/retro_clin/PDa024/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd24/rsub-leads_sim-binary_model-simbio_hemi-R.nii
# File found. Loading and processing right hemisphere...
# Loading NIfTI file from /Volumes/MORRISON/retro_clin/PDa024/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd24/rsub-leads_sim-binary_model-simbio_hemi-R.nii with memory mapping...
# NIfTI file loaded from /Volumes/MORRISON/retro_clin/PDa024/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd24/rsub-leads_sim-binary_model-simbio_hemi-R.nii.
# Right hemisphere processed.
# Checking file existence for left hemisphere: /Volumes/MORRISON/retro_clin/PDa024/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd24/rsub-leads_sim-binary_model-simbio_hemi-L.nii
# File found. Loading and processing left hemisphere...
# Loading NIfTI file from /Volumes/MORRISON/retro_clin/PDa024/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd24/rsub-leads_sim-binary_model-simbio_hemi-L.nii with memory mapping...
# NIfTI file loaded from /Volumes/MORRISON/retro_clin/PDa024/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd24/rsub-leads_sim-binary_model-simbio_hemi-L.nii.
# Left hemisphere processed.
# Finished processing patient PDa024.
# Processing patient 20/268: PDa025
# Checking file existence for right hemisphere: /Volumes/MORRISON/retro_clin/PDa025/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd25/rsub-leads_sim-binary_model-simbio_hemi-R.nii
# File found. Loading and processing right hemisphere...
# Loading NIfTI file from /Volumes/MORRISON/retro_clin/PDa025/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd25/rsub-leads_sim-binary_model-simbio_hemi-R.nii with memory mapping...
# NIfTI file loaded from /Volumes/MORRISON/retro_clin/PDa025/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd25/rsub-leads_sim-binary_model-simbio_hemi-R.nii.
# Right hemisphere processed.
# Checking file existence for left hemisphere: /Volumes/MORRISON/retro_clin/PDa025/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd25/rsub-leads_sim-binary_model-simbio_hemi-L.nii
# File not found for left hemisphere. Using default mask.
# Finished processing patient PDa025.
# Processing patient 21/268: PDa028
# Checking file existence for right hemisphere: /Volumes/MORRISON/retro_clin/PDa028/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd28/rsub-leads_sim-binary_model-simbio_hemi-R.nii
# File not found for right hemisphere. Using default mask.
# Checking file existence for left hemisphere: /Volumes/MORRISON/retro_clin/PDa028/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd28/rsub-leads_sim-binary_model-simbio_hemi-L.nii
# File not found for left hemisphere. Using default mask.
# Finished processing patient PDa028.
# Processing patient 22/268: PDa029
# Checking file existence for right hemisphere: /Volumes/MORRISON/retro_clin/PDa029/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd29/rsub-leads_sim-binary_model-simbio_hemi-R.nii
# File found. Loading and processing right hemisphere...
# Loading NIfTI file from /Volumes/MORRISON/retro_clin/PDa029/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd29/rsub-leads_sim-binary_model-simbio_hemi-R.nii with memory mapping...
# NIfTI file loaded from /Volumes/MORRISON/retro_clin/PDa029/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd29/rsub-leads_sim-binary_model-simbio_hemi-R.nii.
# Right hemisphere processed.
# Checking file existence for left hemisphere: /Volumes/MORRISON/retro_clin/PDa029/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd29/rsub-leads_sim-binary_model-simbio_hemi-L.nii
# File not found for left hemisphere. Using default mask.
# Finished processing patient PDa029.
# Processing patient 23/268: PDa030
# Checking file existence for right hemisphere: /Volumes/MORRISON/retro_clin/PDa030/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd30/rsub-leads_sim-binary_model-simbio_hemi-R.nii
# File not found for right hemisphere. Using default mask.
# Checking file existence for left hemisphere: /Volumes/MORRISON/retro_clin/PDa030/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd30/rsub-leads_sim-binary_model-simbio_hemi-L.nii
# File not found for left hemisphere. Using default mask.
# Finished processing patient PDa030.
# Processing patient 24/268: PDa031
# Checking file existence for right hemisphere: /Volumes/MORRISON/retro_clin/PDa031/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd31/rsub-leads_sim-binary_model-simbio_hemi-R.nii
# File found. Loading and processing right hemisphere...
# Loading NIfTI file from /Volumes/MORRISON/retro_clin/PDa031/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd31/rsub-leads_sim-binary_model-simbio_hemi-R.nii with memory mapping...
# NIfTI file loaded from /Volumes/MORRISON/retro_clin/PDa031/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd31/rsub-leads_sim-binary_model-simbio_hemi-R.nii.
# Right hemisphere processed.
# Checking file existence for left hemisphere: /Volumes/MORRISON/retro_clin/PDa031/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd31/rsub-leads_sim-binary_model-simbio_hemi-L.nii
# File found. Loading and processing left hemisphere...
# Loading NIfTI file from /Volumes/MORRISON/retro_clin/PDa031/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd31/rsub-leads_sim-binary_model-simbio_hemi-L.nii with memory mapping...
# NIfTI file loaded from /Volumes/MORRISON/retro_clin/PDa031/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd31/rsub-leads_sim-binary_model-simbio_hemi-L.nii.
# Left hemisphere processed.
# Finished processing patient PDa031.
# Processing patient 25/268: PDa032
# Checking file existence for right hemisphere: /Volumes/MORRISON/retro_clin/PDa032/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd32/rsub-leads_sim-binary_model-simbio_hemi-R.nii
# File found. Loading and processing right hemisphere...
# Loading NIfTI file from /Volumes/MORRISON/retro_clin/PDa032/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd32/rsub-leads_sim-binary_model-simbio_hemi-R.nii with memory mapping...
# NIfTI file loaded from /Volumes/MORRISON/retro_clin/PDa032/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd32/rsub-leads_sim-binary_model-simbio_hemi-R.nii.
# Right hemisphere processed.
# Checking file existence for left hemisphere: /Volumes/MORRISON/retro_clin/PDa032/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd32/rsub-leads_sim-binary_model-simbio_hemi-L.nii
# File not found for left hemisphere. Using default mask.
# Finished processing patient PDa032.
# Processing patient 26/268: PDa033
# Checking file existence for right hemisphere: /Volumes/MORRISON/retro_clin/PDa033/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd33/rsub-leads_sim-binary_model-simbio_hemi-R.nii
# File not found for right hemisphere. Using default mask.
# Checking file existence for left hemisphere: /Volumes/MORRISON/retro_clin/PDa033/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd33/rsub-leads_sim-binary_model-simbio_hemi-L.nii
# File not found for left hemisphere. Using default mask.
# Finished processing patient PDa033.
# Processing patient 27/268: PDa034
# Checking file existence for right hemisphere: /Volumes/MORRISON/retro_clin/PDa034/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd34/rsub-leads_sim-binary_model-simbio_hemi-R.nii
# File not found for right hemisphere. Using default mask.
# Checking file existence for left hemisphere: /Volumes/MORRISON/retro_clin/PDa034/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd34/rsub-leads_sim-binary_model-simbio_hemi-L.nii
# File not found for left hemisphere. Using default mask.
# Finished processing patient PDa034.
# Processing patient 28/268: PDa035
# Checking file existence for right hemisphere: /Volumes/MORRISON/retro_clin/PDa035/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd35/rsub-leads_sim-binary_model-simbio_hemi-R.nii
# File found. Loading and processing right hemisphere...
# Loading NIfTI file from /Volumes/MORRISON/retro_clin/PDa035/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd35/rsub-leads_sim-binary_model-simbio_hemi-R.nii with memory mapping...
# NIfTI file loaded from /Volumes/MORRISON/retro_clin/PDa035/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd35/rsub-leads_sim-binary_model-simbio_hemi-R.nii.
# Right hemisphere processed.
# Checking file existence for left hemisphere: /Volumes/MORRISON/retro_clin/PDa035/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd35/rsub-leads_sim-binary_model-simbio_hemi-L.nii
# File not found for left hemisphere. Using default mask.
# Finished processing patient PDa035.
# Processing patient 29/268: PDa036
# Checking file existence for right hemisphere: /Volumes/MORRISON/retro_clin/PDa036/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd36/rsub-leads_sim-binary_model-simbio_hemi-R.nii
# File not found for right hemisphere. Using default mask.
# Checking file existence for left hemisphere: /Volumes/MORRISON/retro_clin/PDa036/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd36/rsub-leads_sim-binary_model-simbio_hemi-L.nii
# File not found for left hemisphere. Using default mask.
# Finished processing patient PDa036.
# Processing patient 30/268: PDa037
# Checking file existence for right hemisphere: /Volumes/MORRISON/retro_clin/PDa037/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd37/rsub-leads_sim-binary_model-simbio_hemi-R.nii
# File found. Loading and processing right hemisphere...
# Loading NIfTI file from /Volumes/MORRISON/retro_clin/PDa037/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd37/rsub-leads_sim-binary_model-simbio_hemi-R.nii with memory mapping...
# NIfTI file loaded from /Volumes/MORRISON/retro_clin/PDa037/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd37/rsub-leads_sim-binary_model-simbio_hemi-R.nii.
# Right hemisphere processed.
# Checking file existence for left hemisphere: /Volumes/MORRISON/retro_clin/PDa037/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd37/rsub-leads_sim-binary_model-simbio_hemi-L.nii
# File not found for left hemisphere. Using default mask.
# Finished processing patient PDa037.
# Processing patient 31/268: PDa038
# Checking file existence for right hemisphere: /Volumes/MORRISON/retro_clin/PDa038/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd38/rsub-leads_sim-binary_model-simbio_hemi-R.nii
# File not found for right hemisphere. Using default mask.
# Checking file existence for left hemisphere: /Volumes/MORRISON/retro_clin/PDa038/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd38/rsub-leads_sim-binary_model-simbio_hemi-L.nii
# File not found for left hemisphere. Using default mask.
# Finished processing patient PDa038.
# Processing patient 32/268: PDa039
# Checking file existence for right hemisphere: /Volumes/MORRISON/retro_clin/PDa039/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd39/rsub-leads_sim-binary_model-simbio_hemi-R.nii
# File not found for right hemisphere. Using default mask.
# Checking file existence for left hemisphere: /Volumes/MORRISON/retro_clin/PDa039/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd39/rsub-leads_sim-binary_model-simbio_hemi-L.nii
# File found. Loading and processing left hemisphere...
# Loading NIfTI file from /Volumes/MORRISON/retro_clin/PDa039/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd39/rsub-leads_sim-binary_model-simbio_hemi-L.nii with memory mapping...
# NIfTI file loaded from /Volumes/MORRISON/retro_clin/PDa039/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd39/rsub-leads_sim-binary_model-simbio_hemi-L.nii.
# Left hemisphere processed.
# Finished processing patient PDa039.
# Processing patient 33/268: PDa040
# Checking file existence for right hemisphere: /Volumes/MORRISON/retro_clin/PDa040/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd40/rsub-leads_sim-binary_model-simbio_hemi-R.nii
# File found. Loading and processing right hemisphere...
# Loading NIfTI file from /Volumes/MORRISON/retro_clin/PDa040/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd40/rsub-leads_sim-binary_model-simbio_hemi-R.nii with memory mapping...
# NIfTI file loaded from /Volumes/MORRISON/retro_clin/PDa040/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd40/rsub-leads_sim-binary_model-simbio_hemi-R.nii.
# Right hemisphere processed.
# Checking file existence for left hemisphere: /Volumes/MORRISON/retro_clin/PDa040/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd40/rsub-leads_sim-binary_model-simbio_hemi-L.nii
# File found. Loading and processing left hemisphere...
# Loading NIfTI file from /Volumes/MORRISON/retro_clin/PDa040/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd40/rsub-leads_sim-binary_model-simbio_hemi-L.nii with memory mapping...
# NIfTI file loaded from /Volumes/MORRISON/retro_clin/PDa040/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd40/rsub-leads_sim-binary_model-simbio_hemi-L.nii.
# Left hemisphere processed.
# Finished processing patient PDa040.
# Processing patient 34/268: PDa042
# Checking file existence for right hemisphere: /Volumes/MORRISON/retro_clin/PDa042/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd42/rsub-leads_sim-binary_model-simbio_hemi-R.nii
# File not found for right hemisphere. Using default mask.
# Checking file existence for left hemisphere: /Volumes/MORRISON/retro_clin/PDa042/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd42/rsub-leads_sim-binary_model-simbio_hemi-L.nii
# File not found for left hemisphere. Using default mask.
# Finished processing patient PDa042.
# Processing patient 35/268: PDa043
# Checking file existence for right hemisphere: /Volumes/MORRISON/retro_clin/PDa043/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd43/rsub-leads_sim-binary_model-simbio_hemi-R.nii
# File found. Loading and processing right hemisphere...
# Loading NIfTI file from /Volumes/MORRISON/retro_clin/PDa043/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd43/rsub-leads_sim-binary_model-simbio_hemi-R.nii with memory mapping...
# NIfTI file loaded from /Volumes/MORRISON/retro_clin/PDa043/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd43/rsub-leads_sim-binary_model-simbio_hemi-R.nii.
# Right hemisphere processed.
# Checking file existence for left hemisphere: /Volumes/MORRISON/retro_clin/PDa043/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd43/rsub-leads_sim-binary_model-simbio_hemi-L.nii
# File not found for left hemisphere. Using default mask.
# Finished processing patient PDa043.
# Processing patient 36/268: PDa044
# Checking file existence for right hemisphere: /Volumes/MORRISON/retro_clin/PDa044/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd44/rsub-leads_sim-binary_model-simbio_hemi-R.nii
# File not found for right hemisphere. Using default mask.
# Checking file existence for left hemisphere: /Volumes/MORRISON/retro_clin/PDa044/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd44/rsub-leads_sim-binary_model-simbio_hemi-L.nii
# File not found for left hemisphere. Using default mask.
# Finished processing patient PDa044.
# Processing patient 37/268: PDa045
# Checking file existence for right hemisphere: /Volumes/MORRISON/retro_clin/PDa045/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd45/rsub-leads_sim-binary_model-simbio_hemi-R.nii
# File found. Loading and processing right hemisphere...
# Loading NIfTI file from /Volumes/MORRISON/retro_clin/PDa045/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd45/rsub-leads_sim-binary_model-simbio_hemi-R.nii with memory mapping...
# NIfTI file loaded from /Volumes/MORRISON/retro_clin/PDa045/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd45/rsub-leads_sim-binary_model-simbio_hemi-R.nii.
# Right hemisphere processed.
# Checking file existence for left hemisphere: /Volumes/MORRISON/retro_clin/PDa045/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd45/rsub-leads_sim-binary_model-simbio_hemi-L.nii
# File found. Loading and processing left hemisphere...
# Loading NIfTI file from /Volumes/MORRISON/retro_clin/PDa045/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd45/rsub-leads_sim-binary_model-simbio_hemi-L.nii with memory mapping...
# NIfTI file loaded from /Volumes/MORRISON/retro_clin/PDa045/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd45/rsub-leads_sim-binary_model-simbio_hemi-L.nii.
# Left hemisphere processed.
# Finished processing patient PDa045.
# Processing patient 38/268: PDa046
# Checking file existence for right hemisphere: /Volumes/MORRISON/retro_clin/PDa046/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd46/rsub-leads_sim-binary_model-simbio_hemi-R.nii
# File found. Loading and processing right hemisphere...
# Loading NIfTI file from /Volumes/MORRISON/retro_clin/PDa046/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd46/rsub-leads_sim-binary_model-simbio_hemi-R.nii with memory mapping...
# NIfTI file loaded from /Volumes/MORRISON/retro_clin/PDa046/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd46/rsub-leads_sim-binary_model-simbio_hemi-R.nii.
# Right hemisphere processed.
# Checking file existence for left hemisphere: /Volumes/MORRISON/retro_clin/PDa046/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd46/rsub-leads_sim-binary_model-simbio_hemi-L.nii
# File found. Loading and processing left hemisphere...
# Loading NIfTI file from /Volumes/MORRISON/retro_clin/PDa046/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd46/rsub-leads_sim-binary_model-simbio_hemi-L.nii with memory mapping...
# NIfTI file loaded from /Volumes/MORRISON/retro_clin/PDa046/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd46/rsub-leads_sim-binary_model-simbio_hemi-L.nii.
# Left hemisphere processed.
# Finished processing patient PDa046.
# Processing patient 39/268: PDa047
# Checking file existence for right hemisphere: /Volumes/MORRISON/retro_clin/PDa047/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd47/rsub-leads_sim-binary_model-simbio_hemi-R.nii
# File not found for right hemisphere. Using default mask.
# Checking file existence for left hemisphere: /Volumes/MORRISON/retro_clin/PDa047/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd47/rsub-leads_sim-binary_model-simbio_hemi-L.nii
# File not found for left hemisphere. Using default mask.
# Finished processing patient PDa047.
# Processing patient 40/268: PDa048
# Checking file existence for right hemisphere: /Volumes/MORRISON/retro_clin/PDa048/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd48/rsub-leads_sim-binary_model-simbio_hemi-R.nii
# File found. Loading and processing right hemisphere...
# Loading NIfTI file from /Volumes/MORRISON/retro_clin/PDa048/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd48/rsub-leads_sim-binary_model-simbio_hemi-R.nii with memory mapping...
# NIfTI file loaded from /Volumes/MORRISON/retro_clin/PDa048/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd48/rsub-leads_sim-binary_model-simbio_hemi-R.nii.
# Right hemisphere processed.
# Checking file existence for left hemisphere: /Volumes/MORRISON/retro_clin/PDa048/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd48/rsub-leads_sim-binary_model-simbio_hemi-L.nii
# File found. Loading and processing left hemisphere...
# Loading NIfTI file from /Volumes/MORRISON/retro_clin/PDa048/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd48/rsub-leads_sim-binary_model-simbio_hemi-L.nii with memory mapping...
# NIfTI file loaded from /Volumes/MORRISON/retro_clin/PDa048/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd48/rsub-leads_sim-binary_model-simbio_hemi-L.nii.
# Left hemisphere processed.
# Finished processing patient PDa048.
# Processing patient 41/268: PDa050
# Checking file existence for right hemisphere: /Volumes/MORRISON/retro_clin/PDa050/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd50/rsub-leads_sim-binary_model-simbio_hemi-R.nii
# File found. Loading and processing right hemisphere...
# Loading NIfTI file from /Volumes/MORRISON/retro_clin/PDa050/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd50/rsub-leads_sim-binary_model-simbio_hemi-R.nii with memory mapping...
# NIfTI file loaded from /Volumes/MORRISON/retro_clin/PDa050/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd50/rsub-leads_sim-binary_model-simbio_hemi-R.nii.
# Right hemisphere processed.
# Checking file existence for left hemisphere: /Volumes/MORRISON/retro_clin/PDa050/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd50/rsub-leads_sim-binary_model-simbio_hemi-L.nii
# File found. Loading and processing left hemisphere...
# Loading NIfTI file from /Volumes/MORRISON/retro_clin/PDa050/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd50/rsub-leads_sim-binary_model-simbio_hemi-L.nii with memory mapping...
# NIfTI file loaded from /Volumes/MORRISON/retro_clin/PDa050/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd50/rsub-leads_sim-binary_model-simbio_hemi-L.nii.
# Left hemisphere processed.
# Finished processing patient PDa050.
# Processing patient 42/268: PDa051
# Checking file existence for right hemisphere: /Volumes/MORRISON/retro_clin/PDa051/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd51/rsub-leads_sim-binary_model-simbio_hemi-R.nii
# File not found for right hemisphere. Using default mask.
# Checking file existence for left hemisphere: /Volumes/MORRISON/retro_clin/PDa051/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd51/rsub-leads_sim-binary_model-simbio_hemi-L.nii
# File not found for left hemisphere. Using default mask.
# Finished processing patient PDa051.
# Processing patient 43/268: PDa053
# Checking file existence for right hemisphere: /Volumes/MORRISON/retro_clin/PDa053/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd53/rsub-leads_sim-binary_model-simbio_hemi-R.nii
# File found. Loading and processing right hemisphere...
# Loading NIfTI file from /Volumes/MORRISON/retro_clin/PDa053/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd53/rsub-leads_sim-binary_model-simbio_hemi-R.nii with memory mapping...
# NIfTI file loaded from /Volumes/MORRISON/retro_clin/PDa053/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd53/rsub-leads_sim-binary_model-simbio_hemi-R.nii.
# Right hemisphere processed.
# Checking file existence for left hemisphere: /Volumes/MORRISON/retro_clin/PDa053/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd53/rsub-leads_sim-binary_model-simbio_hemi-L.nii
# File found. Loading and processing left hemisphere...
# Loading NIfTI file from /Volumes/MORRISON/retro_clin/PDa053/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd53/rsub-leads_sim-binary_model-simbio_hemi-L.nii with memory mapping...
# NIfTI file loaded from /Volumes/MORRISON/retro_clin/PDa053/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd53/rsub-leads_sim-binary_model-simbio_hemi-L.nii.
# Left hemisphere processed.
# Finished processing patient PDa053.
# Processing patient 44/268: PDa054
# Checking file existence for right hemisphere: /Volumes/MORRISON/retro_clin/PDa054/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd54/rsub-leads_sim-binary_model-simbio_hemi-R.nii
# File found. Loading and processing right hemisphere...
# Loading NIfTI file from /Volumes/MORRISON/retro_clin/PDa054/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd54/rsub-leads_sim-binary_model-simbio_hemi-R.nii with memory mapping...
# NIfTI file loaded from /Volumes/MORRISON/retro_clin/PDa054/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd54/rsub-leads_sim-binary_model-simbio_hemi-R.nii.
# Right hemisphere processed.
# Checking file existence for left hemisphere: /Volumes/MORRISON/retro_clin/PDa054/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd54/rsub-leads_sim-binary_model-simbio_hemi-L.nii
# File not found for left hemisphere. Using default mask.
# Finished processing patient PDa054.
# Processing patient 45/268: PDa055
# Checking file existence for right hemisphere: /Volumes/MORRISON/retro_clin/PDa055/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd55/rsub-leads_sim-binary_model-simbio_hemi-R.nii
# File not found for right hemisphere. Using default mask.
# Checking file existence for left hemisphere: /Volumes/MORRISON/retro_clin/PDa055/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd55/rsub-leads_sim-binary_model-simbio_hemi-L.nii
# File not found for left hemisphere. Using default mask.
# Finished processing patient PDa055.
# Processing patient 46/268: PDa056
# Checking file existence for right hemisphere: /Volumes/MORRISON/retro_clin/PDa056/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd56/rsub-leads_sim-binary_model-simbio_hemi-R.nii
# File not found for right hemisphere. Using default mask.
# Checking file existence for left hemisphere: /Volumes/MORRISON/retro_clin/PDa056/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd56/rsub-leads_sim-binary_model-simbio_hemi-L.nii
# File not found for left hemisphere. Using default mask.
# Finished processing patient PDa056.
# Processing patient 47/268: PDa057
# Checking file existence for right hemisphere: /Volumes/MORRISON/retro_clin/PDa057/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd57/rsub-leads_sim-binary_model-simbio_hemi-R.nii
# File found. Loading and processing right hemisphere...
# Loading NIfTI file from /Volumes/MORRISON/retro_clin/PDa057/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd57/rsub-leads_sim-binary_model-simbio_hemi-R.nii with memory mapping...
# NIfTI file loaded from /Volumes/MORRISON/retro_clin/PDa057/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd57/rsub-leads_sim-binary_model-simbio_hemi-R.nii.
# Right hemisphere processed.
# Checking file existence for left hemisphere: /Volumes/MORRISON/retro_clin/PDa057/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd57/rsub-leads_sim-binary_model-simbio_hemi-L.nii
# File found. Loading and processing left hemisphere...
# Loading NIfTI file from /Volumes/MORRISON/retro_clin/PDa057/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd57/rsub-leads_sim-binary_model-simbio_hemi-L.nii with memory mapping...
# NIfTI file loaded from /Volumes/MORRISON/retro_clin/PDa057/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd57/rsub-leads_sim-binary_model-simbio_hemi-L.nii.
# Left hemisphere processed.
# Finished processing patient PDa057.
# Processing patient 48/268: PDa058
# Checking file existence for right hemisphere: /Volumes/MORRISON/retro_clin/PDa058/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd58/rsub-leads_sim-binary_model-simbio_hemi-R.nii
# File not found for right hemisphere. Using default mask.
# Checking file existence for left hemisphere: /Volumes/MORRISON/retro_clin/PDa058/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd58/rsub-leads_sim-binary_model-simbio_hemi-L.nii
# File found. Loading and processing left hemisphere...
# Loading NIfTI file from /Volumes/MORRISON/retro_clin/PDa058/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd58/rsub-leads_sim-binary_model-simbio_hemi-L.nii with memory mapping...
# NIfTI file loaded from /Volumes/MORRISON/retro_clin/PDa058/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd58/rsub-leads_sim-binary_model-simbio_hemi-L.nii.
# Left hemisphere processed.
# Finished processing patient PDa058.
# Processing patient 49/268: PDa060
# Checking file existence for right hemisphere: /Volumes/MORRISON/retro_clin/PDa060/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd60/rsub-leads_sim-binary_model-simbio_hemi-R.nii
# File found. Loading and processing right hemisphere...
# Loading NIfTI file from /Volumes/MORRISON/retro_clin/PDa060/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd60/rsub-leads_sim-binary_model-simbio_hemi-R.nii with memory mapping...
# NIfTI file loaded from /Volumes/MORRISON/retro_clin/PDa060/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd60/rsub-leads_sim-binary_model-simbio_hemi-R.nii.
# Right hemisphere processed.
# Checking file existence for left hemisphere: /Volumes/MORRISON/retro_clin/PDa060/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd60/rsub-leads_sim-binary_model-simbio_hemi-L.nii
# File not found for left hemisphere. Using default mask.
# Finished processing patient PDa060.
# Processing patient 50/268: PDa061
# Checking file existence for right hemisphere: /Volumes/MORRISON/retro_clin/PDa061/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd61/rsub-leads_sim-binary_model-simbio_hemi-R.nii
# File not found for right hemisphere. Using default mask.
# Checking file existence for left hemisphere: /Volumes/MORRISON/retro_clin/PDa061/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd61/rsub-leads_sim-binary_model-simbio_hemi-L.nii
# File found. Loading and processing left hemisphere...
# Loading NIfTI file from /Volumes/MORRISON/retro_clin/PDa061/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd61/rsub-leads_sim-binary_model-simbio_hemi-L.nii with memory mapping...
# NIfTI file loaded from /Volumes/MORRISON/retro_clin/PDa061/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd61/rsub-leads_sim-binary_model-simbio_hemi-L.nii.
# Left hemisphere processed.
# Finished processing patient PDa061.
# Processing patient 51/268: PDa062
# Checking file existence for right hemisphere: /Volumes/MORRISON/retro_clin/PDa062/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd62/rsub-leads_sim-binary_model-simbio_hemi-R.nii
# File found. Loading and processing right hemisphere...
# Loading NIfTI file from /Volumes/MORRISON/retro_clin/PDa062/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd62/rsub-leads_sim-binary_model-simbio_hemi-R.nii with memory mapping...
# NIfTI file loaded from /Volumes/MORRISON/retro_clin/PDa062/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd62/rsub-leads_sim-binary_model-simbio_hemi-R.nii.
# Right hemisphere processed.
# Checking file existence for left hemisphere: /Volumes/MORRISON/retro_clin/PDa062/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd62/rsub-leads_sim-binary_model-simbio_hemi-L.nii
# File not found for left hemisphere. Using default mask.
# Finished processing patient PDa062.
# Processing patient 52/268: PDa063
# Checking file existence for right hemisphere: /Volumes/MORRISON/retro_clin/PDa063/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd63/rsub-leads_sim-binary_model-simbio_hemi-R.nii
# File not found for right hemisphere. Using default mask.
# Checking file existence for left hemisphere: /Volumes/MORRISON/retro_clin/PDa063/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd63/rsub-leads_sim-binary_model-simbio_hemi-L.nii
# File not found for left hemisphere. Using default mask.
# Finished processing patient PDa063.

# %%
# Using Scipy.sparse for better memory 

import os
import nibabel as nib
import numpy as np
import pandas as pd
from sklearn.cluster import MiniBatchKMeans
from sklearn.preprocessing import StandardScaler
from scipy import sparse

def load_nifti(file_path):
    """Load a NIfTI file with memory mapping to avoid loading the entire file into memory."""
    print(f"Loading NIfTI file from {file_path} with memory mapping...")
    nifti_data = nib.load(file_path, mmap=True)
    print(f"NIfTI file loaded from {file_path}.")
    return nifti_data.get_fdata()

def binarize_mask(mask):
    """Convert the NIfTI data to a binary mask."""
    binary_mask = np.where(mask > 0, 1, 0)
    return binary_mask

def process_patients_sparse(ledd_data, start_patient, end_patient):
    # Base directory where patient data is stored
    base_dir = '/Volumes/MORRISON/retro_clin'
    all_patient_data = []

    # Set a default shape for missing masks if needed
    default_shape = (394, 466, 378)  # Replace with the actual shape of your NIfTI files

    print("Starting to process each patient...")

    # Loop through each patient, load their stimulation files and binary masks
    for idx, patient_number in enumerate(ledd_data['Patient Number']):
        # Remove the prefix 'PDa' and convert the rest to an integer
        patient_number_int = int(patient_number.replace('PDa', ''))

        # Only process patients within the specified range
        if patient_number_int < start_patient:
            continue
        elif patient_number_int > end_patient:
            print(f"Reached patient number {patient_number}, stopping processing.")
            break

        print(f"Processing patient {idx + 1}/{len(ledd_data['Patient Number'])}: {patient_number}")

        patient_dir = f'PDa{patient_number_int:03d}'
        file_patient_number = str(patient_number_int)
        
        # Define stimulation file paths for both hemispheres
        stim_file_paths = {
            'right': f'{base_dir}/{patient_dir}/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd{file_patient_number}/rsub-leads_sim-binary_model-simbio_hemi-R.nii',
            'left': f'{base_dir}/{patient_dir}/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd{file_patient_number}/rsub-leads_sim-binary_model-simbio_hemi-L.nii'
        }
        
        # Initialize patient data
        patient_data = []
        
        # Load and binarize mask for each hemisphere
        for hemi, path in stim_file_paths.items():
            print(f"Checking file existence for {hemi} hemisphere: {path}")
            if os.path.exists(path):
                print(f"File found. Loading and processing {hemi} hemisphere...")
                mask_data = load_nifti(path)
                binary_mask = binarize_mask(mask_data)
                patient_data.append(binary_mask.flatten())  # Flatten mask to a 1D array for clustering
                print(f"{hemi.capitalize()} hemisphere processed.")
                # Free up memory by deleting large variables that are no longer needed
                del mask_data, binary_mask
            else:
                print(f"File not found for {hemi} hemisphere. Using default mask.")
                default_mask = np.zeros(default_shape)
                patient_data.append(default_mask.flatten())
                # Free up memory for the default mask as well
                del default_mask

        print(f"Finished processing patient {patient_number}.")
        all_patient_data.append(np.concatenate(patient_data))
        # Clear patient_data list to free up memory
        del patient_data

    print("All patients processed. Converting to sparse matrix...")

    # Convert patient data to a sparse matrix for clustering
    patient_data_matrix_sparse = sparse.csr_matrix(np.array(all_patient_data))
    # Clear all_patient_data to free up memory
    del all_patient_data

    # Standardize the data before clustering using sparse matrix operations
    print("Standardizing data (mean centering)...")
    scaler = StandardScaler(with_mean=False)  # `with_mean=False` is used to avoid dense conversion
    scaled_data_sparse = scaler.fit_transform(patient_data_matrix_sparse)
    print("Data standardized.")

    # Apply MiniBatchKMeans clustering
    print("Applying Mini-Batch KMeans clustering on sparse data...")
    mini_batch_kmeans = MiniBatchKMeans(n_clusters=3, random_state=42, batch_size=100)
    clusters = mini_batch_kmeans.fit_predict(scaled_data_sparse)
    print("Mini-Batch KMeans clustering applied on sparse data.")

    # Add cluster labels to LEDD data
    ledd_data['Cluster'] = clusters

    # Save or display the updated DataFrame for analysis
    output_path = '/Users/rwankhalifa/Downloads/clusters.csv'
    ledd_data.to_csv(output_path, index=False)
    print(f"Cluster data saved to {output_path}.")
    print(ledd_data)

# Load LEDD.csv file
ledd_path = '/Users/rwankhalifa/Downloads/LEDD.csv' 
print(f"Loading LEDD data from {ledd_path}...")
ledd_data = pd.read_csv(ledd_path)
print("LEDD data loaded.")

# Add a new column for LEDD value categorization
print("Categorizing LEDD values...")
ledd_data['LEDD_category'] = ledd_data['Delta_LEDD'].apply(lambda x: 'Positive' if x > 0 else ('Negative' if x < 0 else 'Zero'))
print("LEDD values categorized.")

# Process patients from 20 to 144 using the optimized function for sparse matrices
process_patients_sparse(ledd_data, 20, 144)
# Out:
# Loading LEDD data from /Users/rwankhalifa/Downloads/LEDD.csv...
# LEDD data loaded.
# Categorizing LEDD values...
# LEDD values categorized.
# Starting to process each patient...
# Processing patient 15/268: PDa020
# Checking file existence for right hemisphere: /Volumes/MORRISON/retro_clin/PDa020/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd20/rsub-leads_sim-binary_model-simbio_hemi-R.nii
# File found. Loading and processing right hemisphere...
# Loading NIfTI file from /Volumes/MORRISON/retro_clin/PDa020/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd20/rsub-leads_sim-binary_model-simbio_hemi-R.nii with memory mapping...
# NIfTI file loaded from /Volumes/MORRISON/retro_clin/PDa020/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd20/rsub-leads_sim-binary_model-simbio_hemi-R.nii.
# Right hemisphere processed.
# Checking file existence for left hemisphere: /Volumes/MORRISON/retro_clin/PDa020/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd20/rsub-leads_sim-binary_model-simbio_hemi-L.nii
# File found. Loading and processing left hemisphere...
# Loading NIfTI file from /Volumes/MORRISON/retro_clin/PDa020/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd20/rsub-leads_sim-binary_model-simbio_hemi-L.nii with memory mapping...
# NIfTI file loaded from /Volumes/MORRISON/retro_clin/PDa020/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd20/rsub-leads_sim-binary_model-simbio_hemi-L.nii.
# Left hemisphere processed.
# Finished processing patient PDa020.
# Processing patient 16/268: PDa021
# Checking file existence for right hemisphere: /Volumes/MORRISON/retro_clin/PDa021/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd21/rsub-leads_sim-binary_model-simbio_hemi-R.nii
# File found. Loading and processing right hemisphere...
# Loading NIfTI file from /Volumes/MORRISON/retro_clin/PDa021/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd21/rsub-leads_sim-binary_model-simbio_hemi-R.nii with memory mapping...
# NIfTI file loaded from /Volumes/MORRISON/retro_clin/PDa021/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd21/rsub-leads_sim-binary_model-simbio_hemi-R.nii.
# Right hemisphere processed.
# Checking file existence for left hemisphere: /Volumes/MORRISON/retro_clin/PDa021/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd21/rsub-leads_sim-binary_model-simbio_hemi-L.nii
# File not found for left hemisphere. Using default mask.
# Finished processing patient PDa021.
# Processing patient 17/268: PDa022
# Checking file existence for right hemisphere: /Volumes/MORRISON/retro_clin/PDa022/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd22/rsub-leads_sim-binary_model-simbio_hemi-R.nii
# File not found for right hemisphere. Using default mask.
# Checking file existence for left hemisphere: /Volumes/MORRISON/retro_clin/PDa022/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd22/rsub-leads_sim-binary_model-simbio_hemi-L.nii
# File found. Loading and processing left hemisphere...
# Loading NIfTI file from /Volumes/MORRISON/retro_clin/PDa022/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd22/rsub-leads_sim-binary_model-simbio_hemi-L.nii with memory mapping...
# NIfTI file loaded from /Volumes/MORRISON/retro_clin/PDa022/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd22/rsub-leads_sim-binary_model-simbio_hemi-L.nii.
# Left hemisphere processed.
# Finished processing patient PDa022.
# Processing patient 18/268: PDa023
# Checking file existence for right hemisphere: /Volumes/MORRISON/retro_clin/PDa023/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd23/rsub-leads_sim-binary_model-simbio_hemi-R.nii
# File not found for right hemisphere. Using default mask.
# Checking file existence for left hemisphere: /Volumes/MORRISON/retro_clin/PDa023/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd23/rsub-leads_sim-binary_model-simbio_hemi-L.nii
# File found. Loading and processing left hemisphere...
# Loading NIfTI file from /Volumes/MORRISON/retro_clin/PDa023/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd23/rsub-leads_sim-binary_model-simbio_hemi-L.nii with memory mapping...
# NIfTI file loaded from /Volumes/MORRISON/retro_clin/PDa023/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd23/rsub-leads_sim-binary_model-simbio_hemi-L.nii.
# Left hemisphere processed.
# Finished processing patient PDa023.
# Processing patient 19/268: PDa024
# Checking file existence for right hemisphere: /Volumes/MORRISON/retro_clin/PDa024/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd24/rsub-leads_sim-binary_model-simbio_hemi-R.nii
# File found. Loading and processing right hemisphere...
# Loading NIfTI file from /Volumes/MORRISON/retro_clin/PDa024/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd24/rsub-leads_sim-binary_model-simbio_hemi-R.nii with memory mapping...
# NIfTI file loaded from /Volumes/MORRISON/retro_clin/PDa024/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd24/rsub-leads_sim-binary_model-simbio_hemi-R.nii.
# Right hemisphere processed.
# Checking file existence for left hemisphere: /Volumes/MORRISON/retro_clin/PDa024/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd24/rsub-leads_sim-binary_model-simbio_hemi-L.nii
# File found. Loading and processing left hemisphere...
# Loading NIfTI file from /Volumes/MORRISON/retro_clin/PDa024/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd24/rsub-leads_sim-binary_model-simbio_hemi-L.nii with memory mapping...
# NIfTI file loaded from /Volumes/MORRISON/retro_clin/PDa024/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd24/rsub-leads_sim-binary_model-simbio_hemi-L.nii.
# Left hemisphere processed.
# Finished processing patient PDa024.
# Processing patient 20/268: PDa025
# Checking file existence for right hemisphere: /Volumes/MORRISON/retro_clin/PDa025/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd25/rsub-leads_sim-binary_model-simbio_hemi-R.nii
# File found. Loading and processing right hemisphere...
# Loading NIfTI file from /Volumes/MORRISON/retro_clin/PDa025/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd25/rsub-leads_sim-binary_model-simbio_hemi-R.nii with memory mapping...
# NIfTI file loaded from /Volumes/MORRISON/retro_clin/PDa025/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd25/rsub-leads_sim-binary_model-simbio_hemi-R.nii.
# Right hemisphere processed.
# Checking file existence for left hemisphere: /Volumes/MORRISON/retro_clin/PDa025/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd25/rsub-leads_sim-binary_model-simbio_hemi-L.nii
# File not found for left hemisphere. Using default mask.
# Finished processing patient PDa025.
# Processing patient 21/268: PDa028
# Checking file existence for right hemisphere: /Volumes/MORRISON/retro_clin/PDa028/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd28/rsub-leads_sim-binary_model-simbio_hemi-R.nii
# File not found for right hemisphere. Using default mask.
# Checking file existence for left hemisphere: /Volumes/MORRISON/retro_clin/PDa028/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd28/rsub-leads_sim-binary_model-simbio_hemi-L.nii
# File not found for left hemisphere. Using default mask.
# Finished processing patient PDa028.
# Processing patient 22/268: PDa029
# Checking file existence for right hemisphere: /Volumes/MORRISON/retro_clin/PDa029/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd29/rsub-leads_sim-binary_model-simbio_hemi-R.nii
# File found. Loading and processing right hemisphere...
# Loading NIfTI file from /Volumes/MORRISON/retro_clin/PDa029/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd29/rsub-leads_sim-binary_model-simbio_hemi-R.nii with memory mapping...
# NIfTI file loaded from /Volumes/MORRISON/retro_clin/PDa029/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd29/rsub-leads_sim-binary_model-simbio_hemi-R.nii.
# Right hemisphere processed.
# Checking file existence for left hemisphere: /Volumes/MORRISON/retro_clin/PDa029/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd29/rsub-leads_sim-binary_model-simbio_hemi-L.nii
# File not found for left hemisphere. Using default mask.
# Finished processing patient PDa029.
# Processing patient 23/268: PDa030
# Checking file existence for right hemisphere: /Volumes/MORRISON/retro_clin/PDa030/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd30/rsub-leads_sim-binary_model-simbio_hemi-R.nii
# File not found for right hemisphere. Using default mask.
# Checking file existence for left hemisphere: /Volumes/MORRISON/retro_clin/PDa030/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd30/rsub-leads_sim-binary_model-simbio_hemi-L.nii
# File not found for left hemisphere. Using default mask.
# Finished processing patient PDa030.
# Processing patient 24/268: PDa031
# Checking file existence for right hemisphere: /Volumes/MORRISON/retro_clin/PDa031/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd31/rsub-leads_sim-binary_model-simbio_hemi-R.nii
# File found. Loading and processing right hemisphere...
# Loading NIfTI file from /Volumes/MORRISON/retro_clin/PDa031/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd31/rsub-leads_sim-binary_model-simbio_hemi-R.nii with memory mapping...
# NIfTI file loaded from /Volumes/MORRISON/retro_clin/PDa031/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd31/rsub-leads_sim-binary_model-simbio_hemi-R.nii.
# Right hemisphere processed.
# Checking file existence for left hemisphere: /Volumes/MORRISON/retro_clin/PDa031/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd31/rsub-leads_sim-binary_model-simbio_hemi-L.nii
# File found. Loading and processing left hemisphere...
# Loading NIfTI file from /Volumes/MORRISON/retro_clin/PDa031/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd31/rsub-leads_sim-binary_model-simbio_hemi-L.nii with memory mapping...
# NIfTI file loaded from /Volumes/MORRISON/retro_clin/PDa031/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd31/rsub-leads_sim-binary_model-simbio_hemi-L.nii.
# Left hemisphere processed.
# Finished processing patient PDa031.
# Processing patient 25/268: PDa032
# Checking file existence for right hemisphere: /Volumes/MORRISON/retro_clin/PDa032/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd32/rsub-leads_sim-binary_model-simbio_hemi-R.nii
# File found. Loading and processing right hemisphere...
# Loading NIfTI file from /Volumes/MORRISON/retro_clin/PDa032/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd32/rsub-leads_sim-binary_model-simbio_hemi-R.nii with memory mapping...
# NIfTI file loaded from /Volumes/MORRISON/retro_clin/PDa032/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd32/rsub-leads_sim-binary_model-simbio_hemi-R.nii.
# Right hemisphere processed.
# Checking file existence for left hemisphere: /Volumes/MORRISON/retro_clin/PDa032/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd32/rsub-leads_sim-binary_model-simbio_hemi-L.nii
# File not found for left hemisphere. Using default mask.
# Finished processing patient PDa032.
# Processing patient 26/268: PDa033
# Checking file existence for right hemisphere: /Volumes/MORRISON/retro_clin/PDa033/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd33/rsub-leads_sim-binary_model-simbio_hemi-R.nii
# File not found for right hemisphere. Using default mask.
# Checking file existence for left hemisphere: /Volumes/MORRISON/retro_clin/PDa033/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd33/rsub-leads_sim-binary_model-simbio_hemi-L.nii
# File not found for left hemisphere. Using default mask.
# Finished processing patient PDa033.
# Processing patient 27/268: PDa034
# Checking file existence for right hemisphere: /Volumes/MORRISON/retro_clin/PDa034/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd34/rsub-leads_sim-binary_model-simbio_hemi-R.nii
# File not found for right hemisphere. Using default mask.
# Checking file existence for left hemisphere: /Volumes/MORRISON/retro_clin/PDa034/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd34/rsub-leads_sim-binary_model-simbio_hemi-L.nii
# File not found for left hemisphere. Using default mask.
# Finished processing patient PDa034.
# Processing patient 28/268: PDa035
# Checking file existence for right hemisphere: /Volumes/MORRISON/retro_clin/PDa035/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd35/rsub-leads_sim-binary_model-simbio_hemi-R.nii
# File found. Loading and processing right hemisphere...
# Loading NIfTI file from /Volumes/MORRISON/retro_clin/PDa035/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd35/rsub-leads_sim-binary_model-simbio_hemi-R.nii with memory mapping...
# NIfTI file loaded from /Volumes/MORRISON/retro_clin/PDa035/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd35/rsub-leads_sim-binary_model-simbio_hemi-R.nii.
# Right hemisphere processed.
# Checking file existence for left hemisphere: /Volumes/MORRISON/retro_clin/PDa035/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd35/rsub-leads_sim-binary_model-simbio_hemi-L.nii
# File not found for left hemisphere. Using default mask.
# Finished processing patient PDa035.
# Processing patient 29/268: PDa036
# Checking file existence for right hemisphere: /Volumes/MORRISON/retro_clin/PDa036/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd36/rsub-leads_sim-binary_model-simbio_hemi-R.nii
# File not found for right hemisphere. Using default mask.
# Checking file existence for left hemisphere: /Volumes/MORRISON/retro_clin/PDa036/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd36/rsub-leads_sim-binary_model-simbio_hemi-L.nii
# File not found for left hemisphere. Using default mask.
# Finished processing patient PDa036.
# Processing patient 30/268: PDa037
# Checking file existence for right hemisphere: /Volumes/MORRISON/retro_clin/PDa037/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd37/rsub-leads_sim-binary_model-simbio_hemi-R.nii
# File found. Loading and processing right hemisphere...
# Loading NIfTI file from /Volumes/MORRISON/retro_clin/PDa037/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd37/rsub-leads_sim-binary_model-simbio_hemi-R.nii with memory mapping...
# NIfTI file loaded from /Volumes/MORRISON/retro_clin/PDa037/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd37/rsub-leads_sim-binary_model-simbio_hemi-R.nii.
# Right hemisphere processed.
# Checking file existence for left hemisphere: /Volumes/MORRISON/retro_clin/PDa037/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd37/rsub-leads_sim-binary_model-simbio_hemi-L.nii
# File not found for left hemisphere. Using default mask.
# Finished processing patient PDa037.
# Processing patient 31/268: PDa038
# Checking file existence for right hemisphere: /Volumes/MORRISON/retro_clin/PDa038/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd38/rsub-leads_sim-binary_model-simbio_hemi-R.nii
# File not found for right hemisphere. Using default mask.
# Checking file existence for left hemisphere: /Volumes/MORRISON/retro_clin/PDa038/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd38/rsub-leads_sim-binary_model-simbio_hemi-L.nii
# File not found for left hemisphere. Using default mask.
# Finished processing patient PDa038.
# Processing patient 32/268: PDa039
# Checking file existence for right hemisphere: /Volumes/MORRISON/retro_clin/PDa039/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd39/rsub-leads_sim-binary_model-simbio_hemi-R.nii
# File not found for right hemisphere. Using default mask.
# Checking file existence for left hemisphere: /Volumes/MORRISON/retro_clin/PDa039/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd39/rsub-leads_sim-binary_model-simbio_hemi-L.nii
# File found. Loading and processing left hemisphere...
# Loading NIfTI file from /Volumes/MORRISON/retro_clin/PDa039/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd39/rsub-leads_sim-binary_model-simbio_hemi-L.nii with memory mapping...
# NIfTI file loaded from /Volumes/MORRISON/retro_clin/PDa039/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd39/rsub-leads_sim-binary_model-simbio_hemi-L.nii.

# %%
# Using dimentionality reduction before clustering

import os
import nibabel as nib
import numpy as np
import pandas as pd
from sklearn.cluster import MiniBatchKMeans
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from scipy import sparse

def load_nifti(file_path):
    """Load a NIfTI file with memory mapping to avoid loading the entire file into memory."""
    print(f"Loading NIfTI file from {file_path} with memory mapping...")
    nifti_data = nib.load(file_path, mmap=True)
    print(f"NIfTI file loaded from {file_path}.")
    return nifti_data.get_fdata()

def binarize_mask(mask):
    """Convert the NIfTI data to a binary mask."""
    binary_mask = np.where(mask > 0, 1, 0)
    return binary_mask

def process_patients_with_pca(ledd_data, start_patient, end_patient):
    # Base directory where patient data is stored
    base_dir = '/Volumes/MORRISON/retro_clin'
    all_patient_data = []

    # Set a default shape for missing masks if needed
    default_shape = (394, 466, 378)  # Replace with the actual shape of your NIfTI files

    print("Starting to process each patient...")

    # Loop through each patient, load their stimulation files and binary masks
    for idx, patient_number in enumerate(ledd_data['Patient Number']):
        # Remove the prefix 'PDa' and convert the rest to an integer
        patient_number_int = int(patient_number.replace('PDa', ''))

        # Only process patients within the specified range
        if patient_number_int < start_patient:
            continue
        elif patient_number_int > end_patient:
            print(f"Reached patient number {patient_number}, stopping processing.")
            break

        print(f"Processing patient {idx + 1}/{len(ledd_data['Patient Number'])}: {patient_number}")

        patient_dir = f'PDa{patient_number_int:03d}'
        file_patient_number = str(patient_number_int)
        
        # Define stimulation file paths for both hemispheres
        stim_file_paths = {
            'right': f'{base_dir}/{patient_dir}/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd{file_patient_number}/rsub-leads_sim-binary_model-simbio_hemi-R.nii',
            'left': f'{base_dir}/{patient_dir}/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd{file_patient_number}/rsub-leads_sim-binary_model-simbio_hemi-L.nii'
        }
        
        # Initialize patient data
        patient_data = []
        
        # Load and binarize mask for each hemisphere
        for hemi, path in stim_file_paths.items():
            print(f"Checking file existence for {hemi} hemisphere: {path}")
            if os.path.exists(path):
                print(f"File found. Loading and processing {hemi} hemisphere...")
                mask_data = load_nifti(path)
                binary_mask = binarize_mask(mask_data)
                patient_data.append(binary_mask.flatten())  # Flatten mask to a 1D array for clustering
                print(f"{hemi.capitalize()} hemisphere processed.")
                # Free up memory by deleting large variables that are no longer needed
                del mask_data, binary_mask
            else:
                print(f"File not found for {hemi} hemisphere. Using default mask.")
                default_mask = np.zeros(default_shape)
                patient_data.append(default_mask.flatten())
                # Free up memory for the default mask as well
                del default_mask

        print(f"Finished processing patient {patient_number}.")
        all_patient_data.append(np.concatenate(patient_data))
        # Clear patient_data list to free up memory
        del patient_data

    print("All patients processed. Converting to sparse matrix...")

    # Convert patient data to a sparse matrix for clustering
    patient_data_matrix_sparse = sparse.csr_matrix(np.array(all_patient_data))
    # Clear all_patient_data to free up memory
    del all_patient_data

    # Standardize the data before dimensionality reduction
    print("Standardizing data (mean centering)...")
    scaler = StandardScaler(with_mean=False)  # `with_mean=False` to avoid dense conversion
    scaled_data_sparse = scaler.fit_transform(patient_data_matrix_sparse)
    print("Data standardized.")

    # Apply PCA for dimensionality reduction
    print("Applying PCA for dimensionality reduction...")
    pca = PCA(n_components=50)  # Adjust n_components based on your needs
    reduced_data = pca.fit_transform(scaled_data_sparse.toarray())  # Convert to dense array for PCA
    print("PCA applied. Data dimensionality reduced.")

    # Apply Mini-Batch KMeans clustering on reduced data
    print("Applying Mini-Batch KMeans clustering on reduced data...")
    mini_batch_kmeans = MiniBatchKMeans(n_clusters=3, random_state=42, batch_size=100)
    clusters = mini_batch_kmeans.fit_predict(reduced_data)
    print("Mini-Batch KMeans clustering applied on reduced data.")

    # Add cluster labels to LEDD data
    ledd_data['Cluster'] = clusters

    # Save or display the updated DataFrame for analysis
    output_path = '/Users/rwankhalifa/Downloads/clusters.csv'
    ledd_data.to_csv(output_path, index=False)
    print(f"Cluster data saved to {output_path}.")
    print(ledd_data)

# Load LEDD.csv file
ledd_path = '/Users/rwankhalifa/Downloads/LEDD.csv' 
print(f"Loading LEDD data from {ledd_path}...")
ledd_data = pd.read_csv(ledd_path)
print("LEDD data loaded.")

# Add a new column for LEDD value categorization
print("Categorizing LEDD values...")
ledd_data['LEDD_category'] = ledd_data['Delta_LEDD'].apply(lambda x: 'Positive' if x > 0 else ('Negative' if x < 0 else 'Zero'))
print("LEDD values categorized.")
# Out:
# Loading LEDD data from /Users/rwankhalifa/Downloads/LEDD.csv...
# LEDD data loaded.
# Categorizing LEDD values...
# LEDD values categorized.

# %%
# Process patients from 20 to 40 using PCA for dimensionality reduction
process_patients_with_pca(ledd_data, 20, 30)
# Out:
# Starting to process each patient...
# Processing patient 15/268: PDa020
# Checking file existence for right hemisphere: /Volumes/MORRISON/retro_clin/PDa020/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd20/rsub-leads_sim-binary_model-simbio_hemi-R.nii
# File found. Loading and processing right hemisphere...
# Loading NIfTI file from /Volumes/MORRISON/retro_clin/PDa020/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd20/rsub-leads_sim-binary_model-simbio_hemi-R.nii with memory mapping...
# NIfTI file loaded from /Volumes/MORRISON/retro_clin/PDa020/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd20/rsub-leads_sim-binary_model-simbio_hemi-R.nii.
# Right hemisphere processed.
# Checking file existence for left hemisphere: /Volumes/MORRISON/retro_clin/PDa020/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd20/rsub-leads_sim-binary_model-simbio_hemi-L.nii
# File found. Loading and processing left hemisphere...
# Loading NIfTI file from /Volumes/MORRISON/retro_clin/PDa020/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd20/rsub-leads_sim-binary_model-simbio_hemi-L.nii with memory mapping...
# NIfTI file loaded from /Volumes/MORRISON/retro_clin/PDa020/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd20/rsub-leads_sim-binary_model-simbio_hemi-L.nii.
# Left hemisphere processed.
# Finished processing patient PDa020.
# Processing patient 16/268: PDa021
# Checking file existence for right hemisphere: /Volumes/MORRISON/retro_clin/PDa021/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd21/rsub-leads_sim-binary_model-simbio_hemi-R.nii
# File found. Loading and processing right hemisphere...
# Loading NIfTI file from /Volumes/MORRISON/retro_clin/PDa021/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd21/rsub-leads_sim-binary_model-simbio_hemi-R.nii with memory mapping...
# NIfTI file loaded from /Volumes/MORRISON/retro_clin/PDa021/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd21/rsub-leads_sim-binary_model-simbio_hemi-R.nii.
# Right hemisphere processed.
# Checking file existence for left hemisphere: /Volumes/MORRISON/retro_clin/PDa021/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd21/rsub-leads_sim-binary_model-simbio_hemi-L.nii
# File not found for left hemisphere. Using default mask.
# Finished processing patient PDa021.
# Processing patient 17/268: PDa022
# Checking file existence for right hemisphere: /Volumes/MORRISON/retro_clin/PDa022/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd22/rsub-leads_sim-binary_model-simbio_hemi-R.nii
# File not found for right hemisphere. Using default mask.
# Checking file existence for left hemisphere: /Volumes/MORRISON/retro_clin/PDa022/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd22/rsub-leads_sim-binary_model-simbio_hemi-L.nii
# File found. Loading and processing left hemisphere...
# Loading NIfTI file from /Volumes/MORRISON/retro_clin/PDa022/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd22/rsub-leads_sim-binary_model-simbio_hemi-L.nii with memory mapping...
# NIfTI file loaded from /Volumes/MORRISON/retro_clin/PDa022/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd22/rsub-leads_sim-binary_model-simbio_hemi-L.nii.
# Left hemisphere processed.
# Finished processing patient PDa022.
# Processing patient 18/268: PDa023
# Checking file existence for right hemisphere: /Volumes/MORRISON/retro_clin/PDa023/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd23/rsub-leads_sim-binary_model-simbio_hemi-R.nii
# File not found for right hemisphere. Using default mask.
# Checking file existence for left hemisphere: /Volumes/MORRISON/retro_clin/PDa023/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd23/rsub-leads_sim-binary_model-simbio_hemi-L.nii
# File found. Loading and processing left hemisphere...
# Loading NIfTI file from /Volumes/MORRISON/retro_clin/PDa023/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd23/rsub-leads_sim-binary_model-simbio_hemi-L.nii with memory mapping...
# NIfTI file loaded from /Volumes/MORRISON/retro_clin/PDa023/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd23/rsub-leads_sim-binary_model-simbio_hemi-L.nii.
# Left hemisphere processed.
# Finished processing patient PDa023.
# Processing patient 19/268: PDa024
# Checking file existence for right hemisphere: /Volumes/MORRISON/retro_clin/PDa024/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd24/rsub-leads_sim-binary_model-simbio_hemi-R.nii
# File found. Loading and processing right hemisphere...
# Loading NIfTI file from /Volumes/MORRISON/retro_clin/PDa024/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd24/rsub-leads_sim-binary_model-simbio_hemi-R.nii with memory mapping...
# NIfTI file loaded from /Volumes/MORRISON/retro_clin/PDa024/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd24/rsub-leads_sim-binary_model-simbio_hemi-R.nii.
# Right hemisphere processed.
# Checking file existence for left hemisphere: /Volumes/MORRISON/retro_clin/PDa024/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd24/rsub-leads_sim-binary_model-simbio_hemi-L.nii
# File found. Loading and processing left hemisphere...
# Loading NIfTI file from /Volumes/MORRISON/retro_clin/PDa024/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd24/rsub-leads_sim-binary_model-simbio_hemi-L.nii with memory mapping...
# NIfTI file loaded from /Volumes/MORRISON/retro_clin/PDa024/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd24/rsub-leads_sim-binary_model-simbio_hemi-L.nii.
# Left hemisphere processed.
# Finished processing patient PDa024.
# Processing patient 20/268: PDa025
# Checking file existence for right hemisphere: /Volumes/MORRISON/retro_clin/PDa025/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd25/rsub-leads_sim-binary_model-simbio_hemi-R.nii
# File found. Loading and processing right hemisphere...
# Loading NIfTI file from /Volumes/MORRISON/retro_clin/PDa025/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd25/rsub-leads_sim-binary_model-simbio_hemi-R.nii with memory mapping...
# NIfTI file loaded from /Volumes/MORRISON/retro_clin/PDa025/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd25/rsub-leads_sim-binary_model-simbio_hemi-R.nii.
# Right hemisphere processed.
# Checking file existence for left hemisphere: /Volumes/MORRISON/retro_clin/PDa025/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd25/rsub-leads_sim-binary_model-simbio_hemi-L.nii
# File not found for left hemisphere. Using default mask.
# Finished processing patient PDa025.
# Processing patient 21/268: PDa028
# Checking file existence for right hemisphere: /Volumes/MORRISON/retro_clin/PDa028/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd28/rsub-leads_sim-binary_model-simbio_hemi-R.nii
# File not found for right hemisphere. Using default mask.
# Checking file existence for left hemisphere: /Volumes/MORRISON/retro_clin/PDa028/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd28/rsub-leads_sim-binary_model-simbio_hemi-L.nii
# File not found for left hemisphere. Using default mask.
# Finished processing patient PDa028.
# Processing patient 22/268: PDa029
# Checking file existence for right hemisphere: /Volumes/MORRISON/retro_clin/PDa029/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd29/rsub-leads_sim-binary_model-simbio_hemi-R.nii
# File found. Loading and processing right hemisphere...
# Loading NIfTI file from /Volumes/MORRISON/retro_clin/PDa029/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd29/rsub-leads_sim-binary_model-simbio_hemi-R.nii with memory mapping...
# NIfTI file loaded from /Volumes/MORRISON/retro_clin/PDa029/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd29/rsub-leads_sim-binary_model-simbio_hemi-R.nii.
# Right hemisphere processed.
# Checking file existence for left hemisphere: /Volumes/MORRISON/retro_clin/PDa029/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd29/rsub-leads_sim-binary_model-simbio_hemi-L.nii
# File not found for left hemisphere. Using default mask.
# Finished processing patient PDa029.
# Processing patient 23/268: PDa030
# Checking file existence for right hemisphere: /Volumes/MORRISON/retro_clin/PDa030/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd30/rsub-leads_sim-binary_model-simbio_hemi-R.nii
# File not found for right hemisphere. Using default mask.
# Checking file existence for left hemisphere: /Volumes/MORRISON/retro_clin/PDa030/derivatives/leaddbs/sub-leads/stimulations/MNI152NLin2009bAsym/pd30/rsub-leads_sim-binary_model-simbio_hemi-L.nii
# File not found for left hemisphere. Using default mask.
# Finished processing patient PDa030.
# Reached patient number PDa031, stopping processing.
# All patients processed. Converting to sparse matrix...
# Standardizing data (mean centering)...
# Data standardized.
# Applying PCA for dimensionality reduction...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [3], in <cell line: 2>()
#       1 # Process patients from 20 to 40 using PCA for dimensionality reduction
# ----> 2 process_patients_with_pca(ledd_data, 20, 30)
#
# Input In [2], in process_patients_with_pca(ledd_data, start_patient, end_patient)
#      97 print("Applying PCA for dimensionality reduction...")
#      98 pca = PCA(n_components=50)  # Adjust n_components based on your needs
# ---> 99 reduced_data = pca.fit_transform(scaled_data_sparse.toarray())  # Convert to dense array for PCA
#     100 print("PCA applied. Data dimensionality reduced.")
#     102 # Apply Mini-Batch KMeans clustering on reduced data
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/decomposition/_pca.py:407, in PCA.fit_transform(self, X, y)
#     385 def fit_transform(self, X, y=None):
#     386     """Fit the model with X and apply the dimensionality reduction on X.
#     387
#     388     Parameters
#    (...)
#     405     C-ordered array, use 'np.ascontiguousarray'.
#     406     """
# --> 407     U, S, Vt = self._fit(X)
#     408     U = U[:, : self.n_components_]
#     410     if self.whiten:
#     411         # X_new = X * V / S * sqrt(n_samples) = U * sqrt(n_samples)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/decomposition/_pca.py:457, in PCA._fit(self, X)
#     455 # Call different fits for either full or truncated SVD
#     456 if self._fit_svd_solver == "full":
# --> 457     return self._fit_full(X, n_components)
#     458 elif self._fit_svd_solver in ["arpack", "randomized"]:
#     459     return self._fit_truncated(X, n_components, self._fit_svd_solver)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/decomposition/_pca.py:475, in PCA._fit_full(self, X, n_components)
#     471         raise ValueError(
#     472             "n_components='mle' is only supported if n_samples >= n_features"
#     473         )
#     474 elif not 0 <= n_components <= min(n_samples, n_features):
# --> 475     raise ValueError(
#     476         "n_components=%r must be between 0 and "
#     477         "min(n_samples, n_features)=%r with "
#     478         "svd_solver='full'" % (n_components, min(n_samples, n_features))
#     479     )
#     480 elif n_components >= 1:
#     481     if not isinstance(n_components, numbers.Integral):
#
# ValueError: n_components=50 must be between 0 and min(n_samples, n_features)=9 with svd_solver='full'
